# %%
# %load_ext autoreload
# %autoreload 2

import os
import torch

import sys
sys.path.append("/home/msst/repo/Quantization")
import qlib

model_name='Llama2-7b-hf'
#model_name='Llama-3.2-1B'

DTYPE = torch.float16
fp_model, _ = qlib.load_llama(
	model_name=model_name, 
	device_map='cpu', 
	torch_dtype=DTYPE
)

qmodel = qlib.QuantizedLlamaForCausalLM.from_pretrained(
	f'/home/msst/repo/Quantization/ml/llm/pretrained_models/Llama2-7b-trellis',
	torch_dtype=torch.float16,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# LOL, Im custom!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Some weights of the model checkpoint at /home/msst/repo/Quantization/ml/llm/pretrained_models/Llama2-7b-trellis were not used when initializing QuantizedLlamaForCausalLM: {'model.layers.11.mlp.gate_proj.weight', 'model.layers.23.self_attn.q_proj.weight', 'model.layers.18.self_attn.v_proj.weight', 'model.layers.15.mlp.up_proj.weight', 'model.layers.27.self_attn.v_proj.weight', 'model.layers.10.self_attn.q_proj.weight', 'model.layers.26.mlp.up_proj.weight', 'model.layers.12.self_attn.v_proj.weight', 'model.layers.3.self_attn.o_proj.weight', 'model.layers.24.self_attn.k_proj.weight', 'model.layers.10.self_attn.k_proj.weight', 'model.layers.9.mlp.down_proj.weight', 'model.layers.19.mlp.up_proj.weight', 'model.layers.20.self_attn.q_proj.weight', 'model.layers.3.mlp.gate_proj.weight', 'model.layers.11.self_attn.k_proj.weight', 'model.layers.4.self_attn.k_proj.weight', 'model.layers.14.self_attn.o_proj.weight', 'model.layers.1.self_attn.q_proj.weight', 'model.layers.23.mlp.down_proj.weight', 'model.layers.16.mlp.up_proj.weight', 'model.layers.24.self_attn.q_proj.weight', 'model.layers.15.mlp.down_proj.weight', 'model.layers.29.mlp.up_proj.weight', 'model.layers.2.mlp.gate_proj.weight', 'model.layers.17.self_attn.k_proj.weight', 'model.layers.4.self_attn.o_proj.weight', 'model.layers.1.self_attn.o_proj.weight', 'model.layers.12.mlp.gate_proj.weight', 'model.layers.14.self_attn.k_proj.weight', 'model.layers.27.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.31.mlp.up_proj.weight', 'model.layers.21.mlp.up_proj.weight', 'model.layers.12.self_attn.o_proj.weight', 'model.layers.10.mlp.up_proj.weight', 'model.layers.0.self_attn.k_proj.weight', 'model.layers.14.mlp.up_proj.weight', 'model.layers.20.mlp.gate_proj.weight', 'model.layers.25.self_attn.o_proj.weight', 'model.layers.26.self_attn.k_proj.weight', 'model.layers.18.self_attn.k_proj.weight', 'model.layers.6.self_attn.k_proj.weight', 'model.layers.20.self_attn.v_proj.weight', 'model.layers.14.mlp.down_proj.weight', 'model.layers.2.mlp.down_proj.weight', 'model.layers.5.self_attn.o_proj.weight', 'model.layers.7.self_attn.k_proj.weight', 'model.layers.9.self_attn.v_proj.weight', 'model.layers.10.self_attn.v_proj.weight', 'model.layers.10.mlp.gate_proj.weight', 'model.layers.3.mlp.down_proj.weight', 'model.layers.22.mlp.gate_proj.weight', 'model.layers.27.self_attn.q_proj.weight', 'model.layers.15.self_attn.q_proj.weight', 'model.layers.9.self_attn.o_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.23.self_attn.k_proj.weight', 'model.layers.9.self_attn.k_proj.weight', 'model.layers.0.mlp.up_proj.weight', 'model.layers.25.self_attn.q_proj.weight', 'model.layers.13.self_attn.o_proj.weight', 'model.layers.11.self_attn.q_proj.weight', 'model.layers.22.self_attn.k_proj.weight', 'model.layers.21.self_attn.q_proj.weight', 'model.layers.31.self_attn.q_proj.weight', 'model.layers.8.self_attn.o_proj.weight', 'model.layers.9.mlp.up_proj.weight', 'model.layers.26.self_attn.o_proj.weight', 'model.layers.18.mlp.up_proj.weight', 'model.layers.27.mlp.gate_proj.weight', 'model.layers.7.self_attn.q_proj.weight', 'model.layers.24.mlp.up_proj.weight', 'model.layers.19.mlp.gate_proj.weight', 'model.layers.30.self_attn.o_proj.weight', 'model.layers.24.mlp.down_proj.weight', 'model.layers.8.mlp.gate_proj.weight', 'model.layers.20.mlp.down_proj.weight', 'model.layers.5.self_attn.k_proj.weight', 'model.layers.21.self_attn.k_proj.weight', 'model.layers.4.mlp.down_proj.weight', 'model.layers.22.mlp.down_proj.weight', 'model.layers.14.mlp.gate_proj.weight', 'model.layers.3.self_attn.k_proj.weight', 'model.layers.14.self_attn.v_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.1.mlp.down_proj.weight', 'model.layers.18.self_attn.q_proj.weight', 'model.layers.25.mlp.gate_proj.weight', 'model.layers.21.self_attn.v_proj.weight', 'model.layers.31.self_attn.o_proj.weight', 'model.layers.19.self_attn.o_proj.weight', 'model.layers.8.self_attn.q_proj.weight', 'mod ...
# - This IS expected if you are initializing QuantizedLlamaForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing QuantizedLlamaForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of QuantizedLlamaForCausalLM were not initialized from the model checkpoint at /home/msst/repo/Quantization/ml/llm/pretrained_models/Llama2-7b-trellis and are newly initialized: ['model.layers.0.mlp.down_proj.SU', 'model.layers.0.mlp.down_proj.trellis', 'model.layers.0.mlp.down_proj.weight_scales', 'model.layers.0.mlp.gate_proj.SU', 'model.layers.0.mlp.gate_proj.trellis', 'model.layers.0.mlp.gate_proj.weight_scales', 'model.layers.0.mlp.up_proj.SU', 'model.layers.0.mlp.up_proj.trellis', 'model.layers.0.mlp.up_proj.weight_scales', 'model.layers.0.self_attn.k_proj.SU', 'model.layers.0.self_attn.k_proj.trellis', 'model.layers.0.self_attn.k_proj.weight_scales', 'model.layers.0.self_attn.o_proj.SU', 'model.layers.0.self_attn.o_proj.trellis', 'model.layers.0.self_attn.o_proj.weight_scales', 'model.layers.0.self_attn.q_proj.SU', 'model.layers.0.self_attn.q_proj.trellis', 'model.layers.0.self_attn.q_proj.weight_scales', 'model.layers.0.self_attn.v_proj.SU', 'model.layers.0.self_attn.v_proj.trellis', 'model.layers.0.self_attn.v_proj.weight_scales', 'model.layers.1.mlp.down_proj.SU', 'model.layers.1.mlp.down_proj.trellis', 'model.layers.1.mlp.down_proj.weight_scales', 'model.layers.1.mlp.gate_proj.SU', 'model.layers.1.mlp.gate_proj.trellis', 'model.layers.1.mlp.gate_proj.weight_scales', 'model.layers.1.mlp.up_proj.SU', 'model.layers.1.mlp.up_proj.trellis', 'model.layers.1.mlp.up_proj.weight_scales', 'model.layers.1.self_attn.k_proj.SU', 'model.layers.1.self_attn.k_proj.trellis', 'model.layers.1.self_attn.k_proj.weight_scales', 'model.layers.1.self_attn.o_proj.SU', 'model.layers.1.self_attn.o_proj.trellis', 'model.layers.1.self_attn.o_proj.weight_scales', 'model.layers.1.self_attn.q_proj.SU', 'model.layers.1.self_attn.q_proj.trellis', 'model.layers.1.self_attn.q_proj.weight_scales', 'model.layers.1.self_attn.v_proj.SU', 'model.layers.1.self_attn.v_proj.trellis', 'model.layers.1.self_attn.v_proj.weight_scales', 'model.layers.10.mlp.down_proj.SU', 'model.layers.10.mlp.down_proj.trellis', 'model.layers.10.mlp.down_proj.weight_scales', 'model.layers.10.mlp.gate_proj.SU', 'model.layers.10.mlp.gate_proj.trellis', 'model.layers.10.mlp.gate_proj.weight_scales', 'model.layers.10.mlp.up_proj.SU', 'model.layers.10.mlp.up_proj.trellis', 'model.layers.10.mlp.up_proj.weight_scales', 'model.layers.10.self_attn.k_proj.SU', 'model.layers.10.self_attn.k_proj.trellis', 'model.layers.10.self_attn.k_proj.weight_scales', 'model.layers.10.self_attn.o_proj.SU', 'model.layers.10.self_attn.o_proj.trellis', 'model.layers.10.self_attn.o_proj.weight_scales', 'model.layers.10.self_attn.q_proj.SU', 'model.layers.10.self_attn.q_proj.trellis', 'model.layers.10.self_attn.q_proj.weight_scales', 'model.layers.10.self_attn.v_proj.SU', 'model.layers.10.self_attn.v_proj.trellis', 'model.layers.10.self_attn.v_proj.weight_scales', 'model.layers.11.mlp.down_proj.SU', 'model.layers.11.mlp.down_proj.trellis', 'model.layers.11.mlp.down_proj.weight_scales', 'model.layers.11.mlp.gate_proj.SU', 'model.layers.11.mlp.gate_proj.trellis', 'model.layers.11.mlp.gate_proj.weight_scales', 'model.layers.11.mlp.up_proj.SU', 'model.layers.11.mlp.up_proj.trellis', 'model.layers.11.mlp.up_proj.weight_scales', 'model.layers.11.self_attn.k_proj.SU', 'model.layers.11.self_attn.k_proj.trellis', 'model.layers.11.self_attn.k_proj.weight_scales', 'model.layers.11.self_attn.o_proj.SU', 'model.layers.11.self_attn.o_proj.trellis', 'model.layers.11.self_attn.o_proj.weight_scales', 'model.layers.11.self_attn.q_proj.SU', 'model.layers.11.self_attn.q_proj.trellis', 'model.layers.11.self_attn.q_proj.weight_scales', 'model.layers.11.self_attn.v_proj.SU', 'model.layers.11.self_attn.v_proj.trellis', 'model.layers.11.self_attn.v_proj.weight_scales', 'model.layers.12.mlp.down_proj.SU', 'model.layers.12.mlp.down_proj.trellis', 'model.layers.12.mlp.down_proj.weight_scales', 'model.layers.12.mlp.gate_proj.SU', 'model.layers.12.mlp.gate_proj.trellis', 'model.layers.12.mlp.gate_proj.weight_scales', 'model.lay ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
for module_name, qmodule in qmodel.named_modules():
    if isinstance(qmodule, qlib.TrellisLinear):
        qmodule.wrap_module(
            fp_model.get_submodule(module_name), 
            verbose=True,
            module_name=module_name)
# Out:
# /home/msst/miniconda3/envs/qenv/lib/python3.10/site-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# model.layers.0.self_attn.q_proj
# 100%|██████████| 256/256 [00:19<00:00, 13.14it/s]
# 100%|██████████| 256/256 [00:19<00:00, 12.91it/s]
# error: 0.078 ± 0.099
# model.layers.0.self_attn.k_proj
# 100%|██████████| 256/256 [00:18<00:00, 13.53it/s]
# 100%|██████████| 256/256 [00:19<00:00, 12.87it/s]
# error: 0.078 ± 0.076
# model.layers.0.self_attn.v_proj
#  16%|█▋        | 42/256 [00:03<00:15, 13.40it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 for module_name, qmodule in qmodel.named_modules():
#       2     if isinstance(qmodule, qlib.TrellisLinear):
# ----> 3         qmodule.wrap_module(
#       4             fp_model.get_submodule(module_name),
#       5             verbose=True,
#       6             module_name=module_name)
#
# File ~/miniconda3/envs/qenv/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/repo/Quantization/qlib/qlayers/VQ2SQ.py:171, in TrellisLinear.wrap_module(self, module, verbose, *args, **kwargs)
#     169 if verbose and kwargs.get('module_name', False):
#     170     print(kwargs['module_name'])
# --> 171 w_inc_scaled_q, states = self.weight_quantizer.quantize(w_inc_scaled)
#     172 if verbose:
#     173     _w_inc_scaled_q, axes, orig_shape, padded_shape = _reshape_to_blocks(w_inc_scaled_q, axes, block_size)
#
# File ~/repo/Quantization/qlib/qlayers/trellis_quantizer.py:380, in TrellisQuantizer.quantize(self, X, batch_size, **kwargs)
#     378 # Fisrt fase
#     379 roll_X = torch.roll(X, self.T // (2 * self.V) * self.V, 1)
# --> 380 state = self.quantize_seq(roll_X, overlap=None, batch_size=batch_size)
#     381 overlap = state[:, self.T // (2 * self.V)] >> self.K * self.V
#     382 # Second fase
#
# File ~/repo/Quantization/qlib/qlayers/trellis_quantizer.py:364, in TrellisQuantizer.quantize_seq(self, X, overlap, **kwargs)
#     362 for i in tqdm(range(len(X))):
#     363     overlap_batch = None if overlap is None else overlap[i]
# --> 364     Qidxs[i] = self.viterbi(X[i], overlap=overlap_batch)
#     365 Qidxs = Qidxs.reshape(n_seq_padded, T // self.V)[:n_seq]
#     366 return Qidxs
#
# File ~/repo/Quantization/qlib/qlayers/trellis_quantizer.py:339, in TrellisQuantizer.viterbi(self, X, overlap)
#     336 final_state[T_v - 1] = torch.argmin(cost, dim=-1)
#     338 for i in range(T_v - 1, 0, -1):
# --> 339     reduced_idx = (final_state[i] >> (self.K * self.V)).long().unsqueeze(1)
#     340     final_state[i-1] = torch.gather(from_state[i], 1, reduced_idx).squeeze(1)
#     342 return final_state.transpose(0, 1)
#
# KeyboardInterrupt:

# %%
tlp = qmodel.config.trellis_linear_params
checkpoints_path = '/home/msst/repo/Quantization/logs/checkpoints_Llama2-7b-hf/trellis/'

qmodel.save_pretrained(
	os.path.join(
		checkpoints_path,
		"test_mx"
	)
)
