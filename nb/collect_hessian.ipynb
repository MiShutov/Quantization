# %%
# %load_ext autoreload
# %autoreload 2


import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from tqdm import tqdm
import nip
import sys
from itertools import islice
sys.path.append("/home/msst/repo/Quantization")
from qlib import QATDataset

# %%
path2model = "/media/msst/ssd_storage/ml/llm/pretrained_models/Llama2-7b-hf"

device_map = {'model.embed_tokens': 0,
                'model.layers.0': 0,
                'model.layers.1': 0,
                'model.layers.2': 0,
                'model.layers.3': 0,
                'model.layers.4': 0,
                'model.layers.5': 0,
                'model.layers.6': 0,
                'model.layers.7': 0,
                'model.layers.8': 0,
                'model.layers.9': 0,
                'model.layers.10': 0,
                'model.layers.11': 0,
                'model.layers.12': 0,
                'model.layers.13': 0,
                'model.layers.14': 0,
                'model.layers.15': 0,
                'model.layers.16': 0,
                'model.layers.17': 0,
                'model.layers.18': 0,
                'model.layers.19': 0,
                'model.layers.20': 0,
                'model.layers.21': 0,
                'model.layers.22': 0,
                'model.layers.23': 0,
                'model.layers.24': 0,
                'model.layers.25': 'cpu',
                'model.layers.26': 'cpu',
                'model.layers.27': 'cpu',
                'model.layers.28': 'cpu',
                'model.layers.29': 'cpu',
                'model.layers.30': 'cpu',
                'model.layers.31': 'cpu',
                'model.norm': 'cpu',
                'model.rotary_emb': 'cpu',
                'lm_head': 'cpu'}

model = AutoModelForCausalLM.from_pretrained(
    path2model,
    torch_dtype="auto",
    device_map=device_map, #"auto",
    offload_folder="./offload",
    offload_state_dict=True,
    low_cpu_mem_usage=True
)


model.eval()
tokenizer = AutoTokenizer.from_pretrained(path2model)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.

# %%
class StatLinear(torch.nn.Module):
    def __init__(self, linear_layer):
        super().__init__()
        self.in_features = linear_layer.in_features
        self.out_features = linear_layer.out_features
        self.weight = linear_layer.weight
        self.bias = linear_layer.bias
        
        self.H = torch.zeros(self.in_features, self.in_features, dtype=torch.float32)
        self.n_samples = 0

    def forward(self, x, **kwargs):
        n_new_samples = x.shape[0]
        self.H *= self.n_samples / (self.n_samples + n_new_samples)
        self.n_samples += n_new_samples

        x_flat = x.detach().reshape(-1, self.in_features).float()
        x_scaled = ((1 / self.n_samples)**0.5 * x_flat).to(self.H.dtype)
        self.H += (x_scaled.T @ x_scaled).cpu()
        return torch.nn.functional.linear(x, self.weight, self.bias)

# %%
# def replace_linear_layers(model):
#     for module_name, module in model.named_children():
#         if isinstance(module, torch.nn.Linear) and module_name != "lm_head":
#             setattr(model, module_name, StatLinear(module))
#         else:
#             replace_linear_layers(module)
#     return model
# replace_linear_layers(model)


def replace_linear_layers(model, module_paths, exclude_layers=("lm_head",), verbose=True):
    replaced_count = 0
    skipped_count = 0
    error_count = 0
    
    for i, module_path in enumerate(module_paths):
        module_name = module_path.split('.')[-1]
        
        # Пропускаем исключенные слои
        if module_name in exclude_layers:
            if verbose:
                print(f"[{i+1}/{len(module_paths)}] Пропускаю исключенный слой: {module_path}")
            skipped_count += 1
            continue
            
        try:
            path_parts = module_path.split('.')
            parent_module = model
            
            # Рекурсивно идем по пути
            for part in path_parts[:-1]:
                parent_module = getattr(parent_module, part)
            
            module_name = path_parts[-1]
            current_module = getattr(parent_module, module_name)
            
            if isinstance(current_module, torch.nn.Linear):
                if verbose:
                    print(f"[{i+1}/{len(module_paths)}] Заменяю: {module_path}")
                setattr(parent_module, module_name, StatLinear(current_module))
                replaced_count += 1
            else:
                if verbose:
                    print(f"[{i+1}/{len(module_paths)}] Пропускаю: {module_path} (не Linear)")
                skipped_count += 1
                
        except AttributeError:
            if verbose:
                print(f"[{i+1}/{len(module_paths)}] Ошибка: модуль не найден: {module_path}")
            error_count += 1
        except Exception as e:
            if verbose:
                print(f"[{i+1}/{len(module_paths)}] Ошибка: {module_path} - {e}")
            error_count += 1
    
    if verbose:
        print(f"\nИтог: заменено {replaced_count}, пропущено {skipped_count}, ошибок {error_count}")
    
    return model


module_paths = []
#for block_id in range(0, 16):
for block_id in range(16, 32):
    for pattern in [
            "model.layers.{}.self_attn.q_proj",
            "model.layers.{}.self_attn.k_proj", 
            "model.layers.{}.self_attn.v_proj",
            "model.layers.{}.self_attn.o_proj",
            "model.layers.{}.mlp.gate_proj",
            "model.layers.{}.mlp.up_proj",
            "model.layers.{}.mlp.down_proj",
        ]:
        module_paths.append(pattern.format(block_id))

replace_linear_layers(model, module_paths, exclude_layers=("lm_head",), verbose=True)

print("done!")
# Out:
# [1/112] Заменяю: model.layers.16.self_attn.q_proj
# [2/112] Заменяю: model.layers.16.self_attn.k_proj
# [3/112] Заменяю: model.layers.16.self_attn.v_proj
# [4/112] Заменяю: model.layers.16.self_attn.o_proj
# [5/112] Заменяю: model.layers.16.mlp.gate_proj
# [6/112] Заменяю: model.layers.16.mlp.up_proj
# [7/112] Заменяю: model.layers.16.mlp.down_proj
# [8/112] Заменяю: model.layers.17.self_attn.q_proj
# [9/112] Заменяю: model.layers.17.self_attn.k_proj
# [10/112] Заменяю: model.layers.17.self_attn.v_proj
# [11/112] Заменяю: model.layers.17.self_attn.o_proj
# [12/112] Заменяю: model.layers.17.mlp.gate_proj
# [13/112] Заменяю: model.layers.17.mlp.up_proj
# [14/112] Заменяю: model.layers.17.mlp.down_proj
# [15/112] Заменяю: model.layers.18.self_attn.q_proj
# [16/112] Заменяю: model.layers.18.self_attn.k_proj
# [17/112] Заменяю: model.layers.18.self_attn.v_proj
# [18/112] Заменяю: model.layers.18.self_attn.o_proj
# [19/112] Заменяю: model.layers.18.mlp.gate_proj
# [20/112] Заменяю: model.layers.18.mlp.up_proj
# [21/112] Заменяю: model.layers.18.mlp.down_proj
# [22/112] Заменяю: model.layers.19.self_attn.q_proj
# [23/112] Заменяю: model.layers.19.self_attn.k_proj
# [24/112] Заменяю: model.layers.19.self_attn.v_proj
# [25/112] Заменяю: model.layers.19.self_attn.o_proj
# [26/112] Заменяю: model.layers.19.mlp.gate_proj
# [27/112] Заменяю: model.layers.19.mlp.up_proj
# [28/112] Заменяю: model.layers.19.mlp.down_proj
# [29/112] Заменяю: model.layers.20.self_attn.q_proj
# [30/112] Заменяю: model.layers.20.self_attn.k_proj
# [31/112] Заменяю: model.layers.20.self_attn.v_proj
# [32/112] Заменяю: model.layers.20.self_attn.o_proj
# [33/112] Заменяю: model.layers.20.mlp.gate_proj
# [34/112] Заменяю: model.layers.20.mlp.up_proj
# [35/112] Заменяю: model.layers.20.mlp.down_proj
# [36/112] Заменяю: model.layers.21.self_attn.q_proj
# [37/112] Заменяю: model.layers.21.self_attn.k_proj
# [38/112] Заменяю: model.layers.21.self_attn.v_proj
# [39/112] Заменяю: model.layers.21.self_attn.o_proj
# [40/112] Заменяю: model.layers.21.mlp.gate_proj
# [41/112] Заменяю: model.layers.21.mlp.up_proj
# [42/112] Заменяю: model.layers.21.mlp.down_proj
# [43/112] Заменяю: model.layers.22.self_attn.q_proj
# [44/112] Заменяю: model.layers.22.self_attn.k_proj
# [45/112] Заменяю: model.layers.22.self_attn.v_proj
# [46/112] Заменяю: model.layers.22.self_attn.o_proj
# [47/112] Заменяю: model.layers.22.mlp.gate_proj
# [48/112] Заменяю: model.layers.22.mlp.up_proj
# [49/112] Заменяю: model.layers.22.mlp.down_proj
# [50/112] Заменяю: model.layers.23.self_attn.q_proj
# [51/112] Заменяю: model.layers.23.self_attn.k_proj
# [52/112] Заменяю: model.layers.23.self_attn.v_proj
# [53/112] Заменяю: model.layers.23.self_attn.o_proj
# [54/112] Заменяю: model.layers.23.mlp.gate_proj
# [55/112] Заменяю: model.layers.23.mlp.up_proj
# [56/112] Заменяю: model.layers.23.mlp.down_proj
# [57/112] Заменяю: model.layers.24.self_attn.q_proj
# [58/112] Заменяю: model.layers.24.self_attn.k_proj
# [59/112] Заменяю: model.layers.24.self_attn.v_proj
# [60/112] Заменяю: model.layers.24.self_attn.o_proj
# [61/112] Заменяю: model.layers.24.mlp.gate_proj
# [62/112] Заменяю: model.layers.24.mlp.up_proj
# [63/112] Заменяю: model.layers.24.mlp.down_proj
# [64/112] Заменяю: model.layers.25.self_attn.q_proj
# [65/112] Заменяю: model.layers.25.self_attn.k_proj
# [66/112] Заменяю: model.layers.25.self_attn.v_proj
# [67/112] Заменяю: model.layers.25.self_attn.o_proj
# [68/112] Заменяю: model.layers.25.mlp.gate_proj
# [69/112] Заменяю: model.layers.25.mlp.up_proj
# [70/112] Заменяю: model.layers.25.mlp.down_proj
# [71/112] Заменяю: model.layers.26.self_attn.q_proj
# [72/112] Заменяю: model.layers.26.self_attn.k_proj
# [73/112] Заменяю: model.layers.26.self_attn.v_proj
# [74/112] Заменяю: model.layers.26.self_attn.o_proj
# [75/112] Заменяю: model.layers.26.mlp.gate_proj
# [76/112] Заменяю: model.layers.26.mlp.up_proj
# [77/112] Заменяю: model.layers.26.mlp.down_proj
# [78/112] Заменяю: model.layers.27.self_attn.q_proj
# [79/112] Заменяю: model.layers.27.self_attn.k_proj
# [80/112] Заменяю: model.layers.27.self_attn.v_proj
# [81/112] Заменяю: model.layers.27.self_attn.o_proj
# [82/112] Заменяю: model.layers.27.mlp.gate_proj
# [83/112] Заменяю: model.layers.27.mlp.up_proj
# [84/112] Заменяю: model.layers.27.mlp.down_proj
# [85/112] Заменяю: model.layers.28.self_attn.q_proj
# [86/112] Заменяю: model.layers.28.self_attn.k_proj
# [87/112] Заменяю: model.layers.28.self_attn.v_proj
# [88/112] Заменяю: model.layers.28.self_attn.o_proj
# [89/112] Заменяю: model.layers.28.mlp.gate_proj
# [90/112] Заменяю: model.layers.28.mlp.up_proj
# [91/112] Заменяю: model.layers.28.mlp.down_proj
# [92/112] Заменяю: model.layers.29.self_attn.q_proj
# [93/112] Заменяю: model.layers.29.self_attn.k_proj
# [94/112] Заменяю: model.layers.29.self_attn.v_proj
# [95/112] Заменяю: model.layers.29.self_attn.o_proj
# [96/112] Заменяю: model.layers.29.mlp.gate_proj
# [97/112] Заменяю: model.layers.29.mlp.up_proj
# [98/112] Заменяю: model.layers.29.mlp.down_proj
# [99/112] Заменяю: model.layers.30.self_attn.q_proj
# [100/112] Заменяю: model.layers.30.self_attn.k_proj
# [101/112] Заменяю: model.layers.30.self_attn.v_proj
# [102/112] Заменяю: model.layers.30.self_attn.o_proj
# [103/112] Заменяю: model.layers.30.mlp.gate_proj
# [104/112] Заменяю: model.layers.30.mlp.up_proj
# [105/112] Заменяю: model.layers.30.mlp.down_proj
# [106/112] Заменяю: model.layers.31.self_attn.q_proj
# [107/112] Заменяю: model.layers.31.self_attn.k_proj
# [108/112] Заменяю: model.layers.31.self_attn.v_proj
# [109/112] Заменяю: model.layers.31.self_attn.o_proj
# [110/112] Заменяю: model.layers.31.mlp.gate_proj
# [111/112] Заменяю: model.layers.31.mlp.up_proj
# [112/112] Заменяю: model.layers.31.mlp.down_proj
#
# Итог: заменено 112, пропущено 0, ошибок 0
# done!

# %%
dataset = QATDataset(
    config=nip.load('/home/msst/repo/Quantization/configs/data/redpajama_train_seqlen4096.yaml'),
    tokenizer=tokenizer,
    return_dict=True
)
dataset.batch_size=1
dataloader = dataset.get_dataloader()
# Out:
# Resolving data files:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
from itertools import islice

max_batches = 64

for batch in tqdm(islice(dataloader, max_batches), total=max_batches):
    with torch.no_grad():
        output = model(**batch)
# Out:
# 100%|██████████| 64/64 [14:16<00:00, 13.39s/it]

# %%
import os

path_to_save = "/media/msst/ssd_storage/ml/llm/XTX/Llama2-7B"
os.makedirs(path_to_save, exist_ok=True)

for module_name, module in tqdm(model.named_modules()):
    if hasattr(module, "H"):
        torch.save(module.H, f"{path_to_save}/{module_name}")
# Out:
# 423it [00:25, 16.71it/s]

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
import torch

H_dict = torch.load("/media/msst/ssd_storage/ml/weights/XTX_Llama2-7B")
# Out:
# /tmp/ipykernel_93757/1551274502.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   H_dict = torch.load("/media/msst/ssd_storage/ml/weights/XTX_Llama2-7B")

# %%
H = H_dict["model.layers.1.mlp.down_proj"].clone()

damp = 0.01 * torch.mean(torch.diag(H))
diag = torch.arange(H.shape[0])
H[diag, diag] += damp

L = torch.linalg.cholesky(H.to(torch.float64))
# Out:
# ---------------------------------------------------------------------------
# _LinAlgError                              Traceback (most recent call last)
# Cell In[7], line 7
#       4 diag = torch.arange(H.shape[0])
#       5 H[diag, diag] += damp
# ----> 7 L = torch.linalg.cholesky(H.to(torch.float64))
#
# _LinAlgError: linalg.cholesky: The factorization could not be completed because the input is not positive-definite (the leading minor of order 8732 is not positive-definite).

# %%
torch.mean(torch.diag(H))
# Out:
# tensor(13.1304)

# %%
damp = 0.01 * torch.mean(torch.diag(H))
diag = torch.arange(H.shape[0])
H[diag, diag] += damp

# %%
x = torch.randn(5, 4096)
H = x.T @ x

damp = 0.01 * torch.mean(torch.diag(H))
diag = torch.arange(H.shape[0])
H[diag, diag] += damp

# %%
H = torch.linalg.cholesky(H)            # L
H = torch.cholesky_inverse(H)           # H^{-1}
H = torch.linalg.cholesky(H, upper=True)
Hinv = H

# %%
for v in m:
    print(v)
# Out:
# tensor(3.3594, dtype=torch.bfloat16)
# tensor(3.7344, dtype=torch.bfloat16)
# tensor(5.5938, dtype=torch.bfloat16)
# tensor(0.3008, dtype=torch.bfloat16)
# tensor(11.3750, dtype=torch.bfloat16)
# tensor(1.2109, dtype=torch.bfloat16)
# tensor(20.5000, dtype=torch.bfloat16)
# tensor(2.8125, dtype=torch.bfloat16)
# tensor(3.3125, dtype=torch.bfloat16)
# tensor(1.7266, dtype=torch.bfloat16)
# tensor(0.4883, dtype=torch.bfloat16)
# tensor(3.9062, dtype=torch.bfloat16)
# tensor(3.6250, dtype=torch.bfloat16)
# tensor(0.7266, dtype=torch.bfloat16)
# tensor(2.3125, dtype=torch.bfloat16)
# tensor(1.0625, dtype=torch.bfloat16)
# tensor(0.4121, dtype=torch.bfloat16)
# tensor(1.5078, dtype=torch.bfloat16)
# tensor(4.4375, dtype=torch.bfloat16)
# tensor(1.5078, dtype=torch.bfloat16)
# tensor(13.3750, dtype=torch.bfloat16)
# tensor(4.5312, dtype=torch.bfloat16)
# tensor(0.6211, dtype=torch.bfloat16)
# tensor(0.1787, dtype=torch.bfloat16)
# tensor(0.4551, dtype=torch.bfloat16)
# tensor(5.4375, dtype=torch.bfloat16)
# tensor(5.4688, dtype=torch.bfloat16)
# tensor(7.7500, dtype=torch.bfloat16)
# tensor(0.2002, dtype=torch.bfloat16)
# tensor(2.3594, dtype=torch.bfloat16)
# tensor(0.3945, dtype=torch.bfloat16)
# tensor(0.1797, dtype=torch.bfloat16)
# tensor(9.9375, dtype=torch.bfloat16)
# tensor(0.2754, dtype=torch.bfloat16)
# tensor(1.7422, dtype=torch.bfloat16)
# tensor(4.1250, dtype=torch.bfloat16)
# tensor(2.4062, dtype=torch.bfloat16)
# tensor(8.9375, dtype=torch.bfloat16)
# tensor(0.4512, dtype=torch.bfloat16)
# tensor(7., dtype=torch.bfloat16)
# tensor(0.5117, dtype=torch.bfloat16)
# tensor(1.5391, dtype=torch.bfloat16)
# tensor(31.8750, dtype=torch.bfloat16)
# tensor(15.3750, dtype=torch.bfloat16)
# tensor(0.5117, dtype=torch.bfloat16)
# tensor(9.1875, dtype=torch.bfloat16)
# tensor(1.1406, dtype=torch.bfloat16)
# tensor(1.2578, dtype=torch.bfloat16)
# tensor(11., dtype=torch.bfloat16)
# tensor(3.5625, dtype=torch.bfloat16)
# tensor(19.2500, dtype=torch.bfloat16)
# tensor(3.1875, dtype=torch.bfloat16)
# tensor(3.4844, dtype=torch.bfloat16)
# tensor(0.6484, dtype=torch.bfloat16)
# tensor(0.7539, dtype=torch.bfloat16)
# tensor(4.1875, dtype=torch.bfloat16)
# tensor(0.7266, dtype=torch.bfloat16)
# tensor(2.9219, dtype=torch.bfloat16)
# tensor(0.7656, dtype=torch.bfloat16)
# tensor(1.0859, dtype=torch.bfloat16)
# tensor(2.1250, dtype=torch.bfloat16)
# tensor(4.9688, dtype=torch.bfloat16)
# tensor(1.3125, dtype=torch.bfloat16)
# tensor(3.2656, dtype=torch.bfloat16)
# tensor(0.5312, dtype=torch.bfloat16)
# tensor(0.4434, dtype=torch.bfloat16)
# tensor(2.1562, dtype=torch.bfloat16)
# tensor(2.9844, dtype=torch.bfloat16)
# tensor(5.5000, dtype=torch.bfloat16)
# tensor(1.6094, dtype=torch.bfloat16)
# tensor(3.7969, dtype=torch.bfloat16)
# tensor(2.8281, dtype=torch.bfloat16)
# tensor(23.8750, dtype=torch.bfloat16)
# tensor(3.6094, dtype=torch.bfloat16)
# tensor(1.1172, dtype=torch.bfloat16)
# tensor(5.2188, dtype=torch.bfloat16)
# tensor(5.1250, dtype=torch.bfloat16)
# tensor(1.1094, dtype=torch.bfloat16)
# tensor(4.0312, dtype=torch.bfloat16)
# tensor(8.7500, dtype=torch.bfloat16)
# tensor(1.0234, dtype=torch.bfloat16)
# tensor(2.5938, dtype=torch.bfloat16)
# tensor(1.6328, dtype=torch.bfloat16)
# tensor(4.2812, dtype=torch.bfloat16)
# tensor(3.3125, dtype=torch.bfloat16)
# tensor(0.7617, dtype=torch.bfloat16)
# tensor(9.8125, dtype=torch.bfloat16)
# tensor(1.3281, dtype=torch.bfloat16)
# tensor(5.4375, dtype=torch.bfloat16)
# tensor(1.3125, dtype=torch.bfloat16)
# tensor(0.3438, dtype=torch.bfloat16)
# tensor(5.8750, dtype=torch.bfloat16)
# tensor(1.0391, dtype=torch.bfloat16)
# tensor(1.6172, dtype=torch.bfloat16)
# tensor(1.5938, dtype=torch.bfloat16)
# tensor(5.8438, dtype=torch.bfloat16)
# tensor(3.0469, dtype=torch.bfloat16)
# tensor(8., dtype=torch.bfloat16)
# tensor(0.5078, dtype=torch.bfloat16)
# tensor(0.1768, dtype=torch.bfloat16)
# tensor(6.1250, dtype=torch.bfloat16)
# tensor(0.9727, dtype=torch.bfloat16)
# tensor(12.6250, dtype=torch.bfloat16)
# tensor(4.6875, dtype=torch.bfloat16)
# tensor(0.9102, dtype=torch.bfloat16)
# tensor(111.5000, dtype=torch.bfloat16)
# tensor(5.8750, dtype=torch.bfloat16)
# tensor(0.9570, dtype=torch.bfloat16)
# tensor(5.8125, dtype=torch.bfloat16)
# tensor(5.0938, dtype=torch.bfloat16)
# tensor(0.3516, dtype=torch.bfloat16)
# tensor(0.6680, dtype=torch.bfloat16)
# tensor(4.0312, dtype=torch.bfloat16)
# tensor(29.2500, dtype=torch.bfloat16)
# tensor(2.3281, dtype=torch.bfloat16)
# tensor(11.3125, dtype=torch.bfloat16)
# tensor(1.3125, dtype=torch.bfloat16)
# tensor(0.5859, dtype=torch.bfloat16)
# tensor(0.7773, dtype=torch.bfloat16)
# tensor(2.7031, dtype=torch.bfloat16)
# tensor(3.7031, dtype=torch.bfloat16)
# tensor(9.6875, dtype=torch.bfloat16)
# tensor(2.2031, dtype=torch.bfloat16)
# tensor(2.5625, dtype=torch.bfloat16)
# tensor(3.0625, dtype=torch.bfloat16)
# tensor(53.2500, dtype=torch.bfloat16)
# tensor(3.7188, dtype=torch.bfloat16)
# tensor(2.9062, dtype=torch.bfloat16)
# tensor(0.6367, dtype=torch.bfloat16)
# tensor(0.9023, dtype=torch.bfloat16)
# tensor(8.9375, dtype=torch.bfloat16)
# tensor(0.6562, dtype=torch.bfloat16)
# tensor(0.8242, dtype=torch.bfloat16)
# tensor(3.2500, dtype=torch.bfloat16)
# tensor(3.1250, dtype=torch.bfloat16)
# tensor(0.4199, dtype=torch.bfloat16)
# tensor(0.9062, dtype=torch.bfloat16)
# tensor(9.4375, dtype=torch.bfloat16)
# tensor(2.7344, dtype=torch.bfloat16)
# tensor(0.7227, dtype=torch.bfloat16)
# tensor(5.6562, dtype=torch.bfloat16)
# tensor(2.3750, dtype=torch.bfloat16)
# tensor(12.3125, dtype=torch.bfloat16)
# tensor(6.5312, dtype=torch.bfloat16)
# tensor(1.7812, dtype=torch.bfloat16)
# tensor(0.5938, dtype=torch.bfloat16)
# tensor(2.7812, dtype=torch.bfloat16)
# tensor(3.6406, dtype=torch.bfloat16)
# tensor(1.5469, dtype=torch.bfloat16)
# tensor(1.9453, dtype=torch.bfloat16)
# tensor(8.1250, dtype=torch.bfloat16)
# tensor(10., dtype=torch.bfloat16)
# tensor(17.5000, dtype=torch.bfloat16)
# tensor(8.1250, dtype=torch.bfloat16)
# tensor(18.7500, dtype=torch.bfloat16)
# tensor(3.0938, dtype=torch.bfloat16)
# tensor(3.3438, dtype=torch.bfloat16)
# tensor(3.7344, dtype=torch.bfloat16)
# tensor(1.7188, dtype=torch.bfloat16)
# tensor(0.8125, dtype=torch.bfloat16)
# tensor(4.2500, dtype=torch.bfloat16)
# tensor(6.0312, dtype=torch.bfloat16)
# tensor(8.5625, dtype=torch.bfloat16)
# tensor(1.4609, dtype=torch.bfloat16)
# tensor(1.7344, dtype=torch.bfloat16)
# tensor(2.5000, dtype=torch.bfloat16)
# tensor(4.1875, dtype=torch.bfloat16)
# tensor(0.3320, dtype=torch.bfloat16)
# tensor(1.9922, dtype=torch.bfloat16)
# tensor(0.8125, dtype=torch.bfloat16)
# tensor(2.6562, dtype=torch.bfloat16)
# tensor(1.9062, dtype=torch.bfloat16)
# tensor(0.1934, dtype=torch.bfloat16)
# tensor(22.3750, dtype=torch.bfloat16)
# tensor(0.7656, dtype=torch.bfloat16)
# tensor(2.4688, dtype=torch.bfloat16)
# tensor(0.7695, dtype=torch.bfloat16)
# tensor(1.4375, dtype=torch.bfloat16)
# tensor(4.6562, dtype=torch.bfloat16)
# tensor(15.6875, dtype=torch.bfloat16)
# tensor(2.8594, dtype=torch.bfloat16)
# tensor(2.1250, dtype=torch.bfloat16)
# tensor(0.9375, dtype=torch.bfloat16)
# tensor(9.5625, dtype=torch.bfloat16)
# tensor(5.3438, dtype=torch.bfloat16)
# tensor(2.8594, dtype=torch.bfloat16)
# tensor(2.1094, dtype=torch.bfloat16)
# tensor(1.1953, dtype=torch.bfloat16)
# tensor(2.9844, dtype=torch.bfloat16)
# tensor(2.2344, dtype=torch.bfloat16)
# tensor(2.2188, dtype=torch.bfloat16)
# tensor(4.3125, dtype=torch.bfloat16)
# tensor(1.2734, dtype=torch.bfloat16)
# tensor(2.3750, dtype=torch.bfloat16)
# tensor(3.6875, dtype=torch.bfloat16)
# tensor(5.6250, dtype=torch.bfloat16)
# tensor(11.8750, dtype=torch.bfloat16)
# tensor(3.3594, dtype=torch.bfloat16)
# tensor(1.8359, dtype=torch.bfloat16)
# tensor(8.9375, dtype=torch.bfloat16)
# tensor(1.7734, dtype=torch.bfloat16)
# tensor(1.8594, dtype=torch.bfloat16)
# tensor(2.6562, dtype=torch.bfloat16)
# tensor(0.1611, dtype=torch.bfloat16)
# tensor(5.5938, dtype=torch.bfloat16)
# tensor(1.1328, dtype=torch.bfloat16)
# tensor(7.0938, dtype=torch.bfloat16)
# tensor(2.1719, dtype=torch.bfloat16)
# tensor(4.5000, dtype=torch.bfloat16)
# tensor(2.3594, dtype=torch.bfloat16)
# tensor(2.2344, dtype=torch.bfloat16)
# tensor(2.5938, dtype=torch.bfloat16)
# tensor(10.5000, dtype=torch.bfloat16)
# tensor(3.6250, dtype=torch.bfloat16)
# tensor(0.6133, dtype=torch.bfloat16)
# tensor(5.8438, dtype=torch.bfloat16)
# tensor(1.3672, dtype=torch.bfloat16)
# tensor(1.3516, dtype=torch.bfloat16)
# tensor(1.5312, dtype=torch.bfloat16)
# tensor(1.2812, dtype=torch.bfloat16)
# tensor(6.6250, dtype=torch.bfloat16)
# tensor(5.9688, dtype=torch.bfloat16)
# tensor(2.4062, dtype=torch.bfloat16)
# tensor(2.9375, dtype=torch.bfloat16)
# tensor(1.3047, dtype=torch.bfloat16)
# tensor(16.1250, dtype=torch.bfloat16)
# tensor(1.3594, dtype=torch.bfloat16)
# tensor(1.4922, dtype=torch.bfloat16)
# tensor(2.4531, dtype=torch.bfloat16)
# tensor(2.3281, dtype=torch.bfloat16)
# tensor(1.2344, dtype=torch.bfloat16)
# tensor(8.6875, dtype=torch.bfloat16)
# tensor(0.1621, dtype=torch.bfloat16)
# tensor(2.4531, dtype=torch.bfloat16)
# tensor(1.8203, dtype=torch.bfloat16)
# tensor(1.6406, dtype=torch.bfloat16)
# tensor(2.7344, dtype=torch.bfloat16)
# tensor(0.6484, dtype=torch.bfloat16)
# tensor(23.1250, dtype=torch.bfloat16)
# tensor(0.2275, dtype=torch.bfloat16)
# tensor(0.9219, dtype=torch.bfloat16)
# tensor(18.6250, dtype=torch.bfloat16)
# tensor(1.0156, dtype=torch.bfloat16)
# tensor(2.9531, dtype=torch.bfloat16)
# tensor(2.1562, dtype=torch.bfloat16)
# tensor(3.2812, dtype=torch.bfloat16)
# tensor(2.3594, dtype=torch.bfloat16)
# tensor(1.7734, dtype=torch.bfloat16)
# tensor(5.9375, dtype=torch.bfloat16)
# tensor(0.5664, dtype=torch.bfloat16)
# tensor(0.7383, dtype=torch.bfloat16)
# tensor(15.3125, dtype=torch.bfloat16)
# tensor(0.7656, dtype=torch.bfloat16)
# tensor(1.5547, dtype=torch.bfloat16)
# tensor(0.7422, dtype=torch.bfloat16)
# tensor(1.1641, dtype=torch.bfloat16)
# tensor(7.3750, dtype=torch.bfloat16)
# tensor(174., dtype=torch.bfloat16)
# tensor(8.8125, dtype=torch.bfloat16)
# tensor(1.2344, dtype=torch.bfloat16)
# tensor(5.8750, dtype=torch.bfloat16)
# tensor(2.7500, dtype=torch.bfloat16)
# tensor(3.5625, dtype=torch.bfloat16)
# tensor(1.3438, dtype=torch.bfloat16)
# tensor(10.3750, dtype=torch.bfloat16)
# tensor(2.9219, dtype=torch.bfloat16)
# tensor(0.2676, dtype=torch.bfloat16)
# tensor(3.3906, dtype=torch.bfloat16)
# tensor(40.7500, dtype=torch.bfloat16)
# tensor(0.2080, dtype=torch.bfloat16)
# tensor(4.9375, dtype=torch.bfloat16)
# tensor(10.5000, dtype=torch.bfloat16)
# tensor(18.3750, dtype=torch.bfloat16)
# tensor(3.0781, dtype=torch.bfloat16)
# tensor(3.2500, dtype=torch.bfloat16)
# tensor(1.8672, dtype=torch.bfloat16)
# tensor(0.4844, dtype=torch.bfloat16)
# tensor(25.2500, dtype=torch.bfloat16)
# tensor(10.8125, dtype=torch.bfloat16)
# tensor(11., dtype=torch.bfloat16)
# tensor(2.6094, dtype=torch.bfloat16)
# tensor(0.3262, dtype=torch.bfloat16)
# tensor(1.2969, dtype=torch.bfloat16)
# tensor(0.1670, dtype=torch.bfloat16)
# tensor(21.3750, dtype=torch.bfloat16)
# tensor(2.5781, dtype=torch.bfloat16)
# tensor(9.8125, dtype=torch.bfloat16)
# tensor(7.9062, dtype=torch.bfloat16)
# tensor(17.8750, dtype=torch.bfloat16)
# tensor(704., dtype=torch.bfloat16)
# tensor(0.7188, dtype=torch.bfloat16)
# tensor(1.1250, dtype=torch.bfloat16)
# tensor(0.6328, dtype=torch.bfloat16)
# tensor(3.4375, dtype=torch.bfloat16)
# tensor(0.3809, dtype=torch.bfloat16)
# tensor(7.0938, dtype=torch.bfloat16)
# tensor(3.8594, dtype=torch.bfloat16)
# tensor(9.9375, dtype=torch.bfloat16)
# tensor(1.7188, dtype=torch.bfloat16)
# tensor(0.1240, dtype=torch.bfloat16)
# tensor(1.3359, dtype=torch.bfloat16)
# tensor(0.3438, dtype=torch.bfloat16)
# tensor(3.0312, dtype=torch.bfloat16)
# tensor(2.4219, dtype=torch.bfloat16)
# tensor(5.3125, dtype=torch.bfloat16)
# tensor(3.7188, dtype=torch.bfloat16)
# tensor(2.6562, dtype=torch.bfloat16)
# tensor(20.8750, dtype=torch.bfloat16)
# tensor(2.4688, dtype=torch.bfloat16)
# tensor(6.6250, dtype=torch.bfloat16)
# tensor(0.1807, dtype=torch.bfloat16)
# tensor(111., dtype=torch.bfloat16)
# tensor(1.2344, dtype=torch.bfloat16)
# tensor(6.0625, dtype=torch.bfloat16)
# tensor(5.5625, dtype=torch.bfloat16)
# tensor(7.9062, dtype=torch.bfloat16)
# tensor(8.3750, dtype=torch.bfloat16)
# tensor(15., dtype=torch.bfloat16)
# tensor(2.9844, dtype=torch.bfloat16)
# tensor(2.5312, dtype=torch.bfloat16)
# tensor(7.6875, dtype=torch.bfloat16)
# tensor(7.4375, dtype=torch.bfloat16)
# tensor(2.6875, dtype=torch.bfloat16)
# tensor(5.7812, dtype=torch.bfloat16)
# tensor(0.8164, dtype=torch.bfloat16)
# tensor(0.6289, dtype=torch.bfloat16)
# tensor(2.8125, dtype=torch.bfloat16)
# tensor(1.0547, dtype=torch.bfloat16)
# tensor(3.4219, dtype=torch.bfloat16)
# tensor(0.8984, dtype=torch.bfloat16)
# tensor(11.6875, dtype=torch.bfloat16)
# tensor(2.3750, dtype=torch.bfloat16)
# tensor(4.5000, dtype=torch.bfloat16)
# tensor(0.5195, dtype=torch.bfloat16)
# tensor(8.9375, dtype=torch.bfloat16)
# tensor(6.2188, dtype=torch.bfloat16)
# tensor(1.1172, dtype=torch.bfloat16)
# tensor(0.2158, dtype=torch.bfloat16)
# tensor(3.2188, dtype=torch.bfloat16)
# tensor(3.0781, dtype=torch.bfloat16)
# tensor(3.4688, dtype=torch.bfloat16)
# tensor(23.3750, dtype=torch.bfloat16)
# tensor(5.5312, dtype=torch.bfloat16)
# tensor(1.0156, dtype=torch.bfloat16)
# tensor(76., dtype=torch.bfloat16)
# tensor(8.3750, dtype=torch.bfloat16)
# tensor(9.9375, dtype=torch.bfloat16)
# tensor(2.2656, dtype=torch.bfloat16)
# tensor(7.6250, dtype=torch.bfloat16)
# tensor(5.4062, dtype=torch.bfloat16)
# tensor(4.4062, dtype=torch.bfloat16)
# tensor(2.2500, dtype=torch.bfloat16)
# tensor(0.5938, dtype=torch.bfloat16)
# tensor(2.2031, dtype=torch.bfloat16)
# tensor(0.5430, dtype=torch.bfloat16)
# tensor(498., dtype=torch.bfloat16)
# tensor(31.3750, dtype=torch.bfloat16)
# tensor(3.6250, dtype=torch.bfloat16)
# tensor(2.4688, dtype=torch.bfloat16)
# tensor(8.4375, dtype=torch.bfloat16)
# tensor(1.4609, dtype=torch.bfloat16)
# tensor(2.2344, dtype=torch.bfloat16)
# tensor(11., dtype=torch.bfloat16)
# tensor(0.2021, dtype=torch.bfloat16)
# tensor(0.3418, dtype=torch.bfloat16)
# tensor(0.3926, dtype=torch.bfloat16)
# tensor(0.2598, dtype=torch.bfloat16)
# tensor(0.6797, dtype=torch.bfloat16)
# tensor(1.7422, dtype=torch.bfloat16)
# tensor(1.6172, dtype=torch.bfloat16)
# tensor(2.6406, dtype=torch.bfloat16)
# tensor(7.3125, dtype=torch.bfloat16)
# tensor(0.8789, dtype=torch.bfloat16)
# tensor(2.5938, dtype=torch.bfloat16)
# tensor(0.8242, dtype=torch.bfloat16)
# tensor(1.2031, dtype=torch.bfloat16)
# tensor(2.7656, dtype=torch.bfloat16)
# tensor(2.0938, dtype=torch.bfloat16)
# tensor(9.3125, dtype=torch.bfloat16)
# tensor(1.1875, dtype=torch.bfloat16)
# tensor(2.3438, dtype=torch.bfloat16)
# tensor(8.5625, dtype=torch.bfloat16)
# tensor(0.6992, dtype=torch.bfloat16)
# tensor(2.8125, dtype=torch.bfloat16)
# tensor(1.7734, dtype=torch.bfloat16)
# tensor(3.5000, dtype=torch.bfloat16)
# tensor(3.8438, dtype=torch.bfloat16)
# tensor(7.9062, dtype=torch.bfloat16)
# tensor(0.8906, dtype=torch.bfloat16)
# tensor(2.7500, dtype=torch.bfloat16)
# tensor(2.4062, dtype=torch.bfloat16)
# tensor(0.2969, dtype=torch.bfloat16)
# tensor(1.3906, dtype=torch.bfloat16)
# tensor(5.2500, dtype=torch.bfloat16)
# tensor(2.5312, dtype=torch.bfloat16)
# tensor(2.4531, dtype=torch.bfloat16)
# tensor(17.3750, dtype=torch.bfloat16)
# tensor(8.4375, dtype=torch.bfloat16)
# tensor(9.5000, dtype=torch.bfloat16)
# tensor(0.5078, dtype=torch.bfloat16)
# tensor(0.4609, dtype=torch.bfloat16)
# tensor(0.9023, dtype=torch.bfloat16)
# tensor(1.1953, dtype=torch.bfloat16)
# tensor(3.7500, dtype=torch.bfloat16)
# tensor(7.8750, dtype=torch.bfloat16)
# tensor(0.3438, dtype=torch.bfloat16)
# tensor(3.7188, dtype=torch.bfloat16)
# tensor(1.4062, dtype=torch.bfloat16)
# tensor(7.9688, dtype=torch.bfloat16)
# tensor(9.1875, dtype=torch.bfloat16)
# tensor(0.8672, dtype=torch.bfloat16)
# tensor(5.5312, dtype=torch.bfloat16)
# tensor(1.9375, dtype=torch.bfloat16)
# tensor(5.6562, dtype=torch.bfloat16)
# tensor(0.2812, dtype=torch.bfloat16)
# tensor(7.2188, dtype=torch.bfloat16)
# tensor(3.6250, dtype=torch.bfloat16)
# tensor(2.6406, dtype=torch.bfloat16)
# tensor(10.4375, dtype=torch.bfloat16)
# tensor(0.7109, dtype=torch.bfloat16)
# tensor(1.0859, dtype=torch.bfloat16)
# tensor(13.8125, dtype=torch.bfloat16)
# tensor(2.2656, dtype=torch.bfloat16)
# tensor(0.5586, dtype=torch.bfloat16)
# tensor(10., dtype=torch.bfloat16)
# tensor(1.0703, dtype=torch.bfloat16)
# tensor(2.1562, dtype=torch.bfloat16)
# tensor(1.1406, dtype=torch.bfloat16)
# tensor(2.3438, dtype=torch.bfloat16)
# tensor(21.5000, dtype=torch.bfloat16)
# tensor(3.6562, dtype=torch.bfloat16)
# tensor(1.5703, dtype=torch.bfloat16)
# tensor(2.6094, dtype=torch.bfloat16)
# tensor(0.6875, dtype=torch.bfloat16)
# tensor(1.2188, dtype=torch.bfloat16)
# tensor(5.5938, dtype=torch.bfloat16)
# tensor(0.3594, dtype=torch.bfloat16)
# tensor(1.4766, dtype=torch.bfloat16)
# tensor(19.3750, dtype=torch.bfloat16)
# tensor(2.6719, dtype=torch.bfloat16)
# tensor(2960., dtype=torch.bfloat16)
# tensor(9.8125, dtype=torch.bfloat16)
# tensor(2.8438, dtype=torch.bfloat16)
# tensor(1.4062, dtype=torch.bfloat16)
# tensor(4.9062, dtype=torch.bfloat16)
# tensor(1.5234, dtype=torch.bfloat16)
# tensor(3.0625, dtype=torch.bfloat16)
# tensor(2.5000, dtype=torch.bfloat16)
# tensor(2.7969, dtype=torch.bfloat16)
# tensor(149., dtype=torch.bfloat16)
# tensor(0.6719, dtype=torch.bfloat16)
# tensor(1.5000, dtype=torch.bfloat16)
# tensor(3.5469, dtype=torch.bfloat16)
# tensor(7.1562, dtype=torch.bfloat16)
# tensor(14.9375, dtype=torch.bfloat16)
# tensor(1.3984, dtype=torch.bfloat16)
# tensor(0.6797, dtype=torch.bfloat16)
# tensor(3., dtype=torch.bfloat16)
# tensor(0.7578, dtype=torch.bfloat16)
# tensor(0.8984, dtype=torch.bfloat16)
# tensor(0.2539, dtype=torch.bfloat16)
# tensor(10., dtype=torch.bfloat16)
# tensor(2.6719, dtype=torch.bfloat16)
# tensor(0.5234, dtype=torch.bfloat16)
# tensor(0.6719, dtype=torch.bfloat16)
# tensor(1.0469, dtype=torch.bfloat16)
# tensor(2.7656, dtype=torch.bfloat16)
# tensor(2.5938, dtype=torch.bfloat16)
# tensor(0.4219, dtype=torch.bfloat16)
# tensor(0.8555, dtype=torch.bfloat16)
# tensor(4.9062, dtype=torch.bfloat16)
# tensor(0.6172, dtype=torch.bfloat16)
# tensor(40.7500, dtype=torch.bfloat16)
# tensor(0.2285, dtype=torch.bfloat16)
# tensor(4.2812, dtype=torch.bfloat16)
# tensor(2.3594, dtype=torch.bfloat16)
# tensor(0.3340, dtype=torch.bfloat16)
# tensor(1.7266, dtype=torch.bfloat16)
# tensor(2.5469, dtype=torch.bfloat16)
# tensor(9.4375, dtype=torch.bfloat16)
# tensor(1.4844, dtype=torch.bfloat16)
# tensor(1.9297, dtype=torch.bfloat16)
# tensor(1.6094, dtype=torch.bfloat16)
# tensor(2.7031, dtype=torch.bfloat16)
# tensor(2.0938, dtype=torch.bfloat16)
# tensor(18.7500, dtype=torch.bfloat16)
# tensor(2.2188, dtype=torch.bfloat16)
# tensor(3.5781, dtype=torch.bfloat16)
# tensor(4.9688, dtype=torch.bfloat16)
# tensor(0.4395, dtype=torch.bfloat16)
# tensor(4.6875, dtype=torch.bfloat16)
# tensor(0.3418, dtype=torch.bfloat16)
# tensor(3.4062, dtype=torch.bfloat16)
# tensor(38.5000, dtype=torch.bfloat16)
# tensor(1.6094, dtype=torch.bfloat16)
# tensor(3.9062, dtype=torch.bfloat16)
# tensor(1.8047, dtype=torch.bfloat16)
# tensor(8.3750, dtype=torch.bfloat16)
# tensor(5.1250, dtype=torch.bfloat16)
# tensor(1.9375, dtype=torch.bfloat16)
# tensor(1.4141, dtype=torch.bfloat16)
# tensor(2.7656, dtype=torch.bfloat16)
# tensor(1.4922, dtype=torch.bfloat16)
# tensor(16.1250, dtype=torch.bfloat16)
# tensor(1.2812, dtype=torch.bfloat16)
# tensor(5.8438, dtype=torch.bfloat16)
# tensor(7.4375, dtype=torch.bfloat16)
# tensor(1.3359, dtype=torch.bfloat16)
# tensor(0.8633, dtype=torch.bfloat16)
# tensor(5.9062, dtype=torch.bfloat16)
# tensor(0.4512, dtype=torch.bfloat16)
# tensor(0.5156, dtype=torch.bfloat16)
# tensor(0.2314, dtype=torch.bfloat16)
# tensor(1.1328, dtype=torch.bfloat16)
# tensor(1.4375, dtype=torch.bfloat16)
# tensor(4.4062, dtype=torch.bfloat16)
# tensor(1.3594, dtype=torch.bfloat16)
# tensor(7.3125, dtype=torch.bfloat16)
# tensor(10.8750, dtype=torch.bfloat16)
# tensor(10.6875, dtype=torch.bfloat16)
# tensor(0.6523, dtype=torch.bfloat16)
# tensor(0.6523, dtype=torch.bfloat16)
# tensor(3.1875, dtype=torch.bfloat16)
# tensor(0.7305, dtype=torch.bfloat16)
# tensor(2.4375, dtype=torch.bfloat16)
# tensor(7.4688, dtype=torch.bfloat16)
# tensor(5.9375, dtype=torch.bfloat16)
# tensor(3.2656, dtype=torch.bfloat16)
# tensor(8.1875, dtype=torch.bfloat16)
# tensor(7.1562, dtype=torch.bfloat16)
# tensor(2.2656, dtype=torch.bfloat16)
# tensor(1., dtype=torch.bfloat16)
# tensor(5.7812, dtype=torch.bfloat16)
# tensor(2.0469, dtype=torch.bfloat16)
# tensor(2.4688, dtype=torch.bfloat16)
# tensor(0.7539, dtype=torch.bfloat16)
# tensor(10.7500, dtype=torch.bfloat16)
# tensor(2.8750, dtype=torch.bfloat16)
# tensor(19.3750, dtype=torch.bfloat16)
# tensor(1.8516, dtype=torch.bfloat16)
# tensor(26.1250, dtype=torch.bfloat16)
# tensor(1.2969, dtype=torch.bfloat16)
# tensor(7.8750, dtype=torch.bfloat16)
# tensor(8.3750, dtype=torch.bfloat16)
# tensor(1.5781, dtype=torch.bfloat16)
# tensor(1.6016, dtype=torch.bfloat16)
# tensor(0.2773, dtype=torch.bfloat16)
# tensor(8.4375, dtype=torch.bfloat16)
# tensor(5.2812, dtype=torch.bfloat16)
# tensor(5.6250, dtype=torch.bfloat16)
# tensor(5.1562, dtype=torch.bfloat16)
# tensor(2.2656, dtype=torch.bfloat16)
# tensor(4.4375, dtype=torch.bfloat16)
# tensor(7., dtype=torch.bfloat16)
# tensor(3.8594, dtype=torch.bfloat16)
# tensor(0.7656, dtype=torch.bfloat16)
# tensor(1.5703, dtype=torch.bfloat16)
# tensor(0.7422, dtype=torch.bfloat16)
# tensor(25.2500, dtype=torch.bfloat16)
# tensor(2.7344, dtype=torch.bfloat16)
# tensor(2.1094, dtype=torch.bfloat16)
# tensor(0.3320, dtype=torch.bfloat16)
# tensor(1.3750, dtype=torch.bfloat16)
# tensor(2.5469, dtype=torch.bfloat16)
# tensor(1.2969, dtype=torch.bfloat16)
# tensor(10., dtype=torch.bfloat16)
# tensor(1.1484, dtype=torch.bfloat16)
# tensor(2.2969, dtype=torch.bfloat16)
# tensor(2.4531, dtype=torch.bfloat16)
# tensor(2.3750, dtype=torch.bfloat16)
# tensor(0.7461, dtype=torch.bfloat16)
# tensor(1.1953, dtype=torch.bfloat16)
# tensor(0.7070, dtype=torch.bfloat16)
# tensor(3.0156, dtype=torch.bfloat16)
# tensor(1.4219, dtype=torch.bfloat16)
# tensor(10.6875, dtype=torch.bfloat16)
# tensor(4.8750, dtype=torch.bfloat16)
# tensor(0.5117, dtype=torch.bfloat16)
# tensor(1.6875, dtype=torch.bfloat16)
# tensor(2.7031, dtype=torch.bfloat16)
# tensor(0.4590, dtype=torch.bfloat16)
# tensor(0.9609, dtype=torch.bfloat16)
# tensor(4.5312, dtype=torch.bfloat16)
# tensor(6., dtype=torch.bfloat16)
# tensor(2.7656, dtype=torch.bfloat16)
# tensor(1.6797, dtype=torch.bfloat16)
# tensor(2.7969, dtype=torch.bfloat16)
# tensor(1.2578, dtype=torch.bfloat16)
# tensor(0.7266, dtype=torch.bfloat16)
# tensor(6.6875, dtype=torch.bfloat16)
# tensor(4.2500, dtype=torch.bfloat16)
# tensor(2.5938, dtype=torch.bfloat16)
# tensor(1.0938, dtype=torch.bfloat16)
# tensor(2.3438, dtype=torch.bfloat16)
# tensor(2.9062, dtype=torch.bfloat16)
# tensor(1.3906, dtype=torch.bfloat16)
# tensor(1.4609, dtype=torch.bfloat16)
# tensor(0.4883, dtype=torch.bfloat16)
# tensor(0.8555, dtype=torch.bfloat16)
# tensor(5.8438, dtype=torch.bfloat16)
# tensor(1.5078, dtype=torch.bfloat16)
# tensor(1., dtype=torch.bfloat16)
# tensor(2.2969, dtype=torch.bfloat16)
# tensor(5.2188, dtype=torch.bfloat16)
# tensor(7.2500, dtype=torch.bfloat16)
# tensor(1.7578, dtype=torch.bfloat16)
# tensor(5.1562, dtype=torch.bfloat16)
# tensor(14.0625, dtype=torch.bfloat16)
# tensor(1.4219, dtype=torch.bfloat16)
# tensor(3.4375, dtype=torch.bfloat16)
# tensor(0.4375, dtype=torch.bfloat16)
# tensor(9.0625, dtype=torch.bfloat16)
# tensor(2.7344, dtype=torch.bfloat16)
# tensor(6., dtype=torch.bfloat16)
# tensor(0.5039, dtype=torch.bfloat16)
# tensor(0.8789, dtype=torch.bfloat16)
# tensor(0.4961, dtype=torch.bfloat16)
# tensor(1.3984, dtype=torch.bfloat16)
# tensor(0.6602, dtype=torch.bfloat16)
# tensor(0.3535, dtype=torch.bfloat16)
# tensor(1.0859, dtype=torch.bfloat16)
# tensor(2.7500, dtype=torch.bfloat16)
# tensor(14.0625, dtype=torch.bfloat16)
# tensor(6.6562, dtype=torch.bfloat16)
# tensor(3.9375, dtype=torch.bfloat16)
# tensor(0.5938, dtype=torch.bfloat16)
# tensor(4.5312, dtype=torch.bfloat16)
# tensor(5.2188, dtype=torch.bfloat16)
# tensor(12.4375, dtype=torch.bfloat16)
# tensor(3.7969, dtype=torch.bfloat16)
# tensor(2.7188, dtype=torch.bfloat16)
# tensor(2.9844, dtype=torch.bfloat16)
# tensor(0.8711, dtype=torch.bfloat16)
# tensor(0.7969, dtype=torch.bfloat16)
# tensor(1.8516, dtype=torch.bfloat16)
# tensor(3.7500, dtype=torch.bfloat16)
# tensor(2.0625, dtype=torch.bfloat16)
# tensor(1.4688, dtype=torch.bfloat16)
# tensor(6.9062, dtype=torch.bfloat16)
# tensor(0.5469, dtype=torch.bfloat16)
# tensor(4.9062, dtype=torch.bfloat16)
# tensor(8.9375, dtype=torch.bfloat16)
# tensor(0.2891, dtype=torch.bfloat16)
# tensor(0.3926, dtype=torch.bfloat16)
# tensor(0.3711, dtype=torch.bfloat16)
# tensor(3.1406, dtype=torch.bfloat16)
# tensor(0.7148, dtype=torch.bfloat16)
# tensor(0.4238, dtype=torch.bfloat16)
# tensor(4.6562, dtype=torch.bfloat16)
# tensor(2.7031, dtype=torch.bfloat16)
# tensor(0.7148, dtype=torch.bfloat16)
# tensor(3.5000, dtype=torch.bfloat16)
# tensor(0.7852, dtype=torch.bfloat16)
# tensor(1.4766, dtype=torch.bfloat16)
# tensor(0.2598, dtype=torch.bfloat16)
# tensor(1.6875, dtype=torch.bfloat16)
# tensor(11.8750, dtype=torch.bfloat16)
# tensor(0.7031, dtype=torch.bfloat16)
# tensor(4.0312, dtype=torch.bfloat16)
# tensor(1.5703, dtype=torch.bfloat16)
# tensor(3.3594, dtype=torch.bfloat16)
# tensor(19.7500, dtype=torch.bfloat16)
# tensor(2.3438, dtype=torch.bfloat16)
# tensor(3.1406, dtype=torch.bfloat16)
# tensor(4.8750, dtype=torch.bfloat16)
# tensor(2.9375, dtype=torch.bfloat16)
# tensor(2.9531, dtype=torch.bfloat16)
# tensor(6.4375, dtype=torch.bfloat16)
# tensor(5.7812, dtype=torch.bfloat16)
# tensor(1.3047, dtype=torch.bfloat16)
# tensor(0.6602, dtype=torch.bfloat16)
# tensor(9.2500, dtype=torch.bfloat16)
# tensor(1.4453, dtype=torch.bfloat16)
# tensor(2.6562, dtype=torch.bfloat16)
# tensor(5.8125, dtype=torch.bfloat16)
# tensor(1.9609, dtype=torch.bfloat16)
# tensor(10.6875, dtype=torch.bfloat16)
# tensor(2.0625, dtype=torch.bfloat16)
# tensor(1.9453, dtype=torch.bfloat16)
# tensor(4.5312, dtype=torch.bfloat16)
# tensor(3.8125, dtype=torch.bfloat16)
# tensor(0.2354, dtype=torch.bfloat16)
# tensor(5.8125, dtype=torch.bfloat16)
# tensor(2.8750, dtype=torch.bfloat16)
# tensor(1.3438, dtype=torch.bfloat16)
# tensor(9.5000, dtype=torch.bfloat16)
# tensor(0.8984, dtype=torch.bfloat16)
# tensor(5.7500, dtype=torch.bfloat16)
# tensor(0.3145, dtype=torch.bfloat16)
# tensor(0.4922, dtype=torch.bfloat16)
# tensor(12.1875, dtype=torch.bfloat16)
# tensor(4.1875, dtype=torch.bfloat16)
# tensor(0.2871, dtype=torch.bfloat16)
# tensor(5.7500, dtype=torch.bfloat16)
# tensor(10.2500, dtype=torch.bfloat16)
# tensor(3.2969, dtype=torch.bfloat16)
# tensor(0.3340, dtype=torch.bfloat16)
# tensor(2.4375, dtype=torch.bfloat16)
# tensor(1.7500, dtype=torch.bfloat16)
# tensor(0.4336, dtype=torch.bfloat16)
# tensor(1.1797, dtype=torch.bfloat16)
# tensor(0.2266, dtype=torch.bfloat16)
# tensor(1.3594, dtype=torch.bfloat16)
# tensor(0.5312, dtype=torch.bfloat16)
# tensor(4.8750, dtype=torch.bfloat16)
# tensor(2.3125, dtype=torch.bfloat16)
# tensor(3.1719, dtype=torch.bfloat16)
# tensor(0.6367, dtype=torch.bfloat16)
# tensor(11.5625, dtype=torch.bfloat16)
# tensor(11., dtype=torch.bfloat16)
# tensor(7.4688, dtype=torch.bfloat16)
# tensor(12., dtype=torch.bfloat16)
# tensor(19.8750, dtype=torch.bfloat16)
# tensor(1.4141, dtype=torch.bfloat16)
# tensor(1.5781, dtype=torch.bfloat16)
# tensor(5.2188, dtype=torch.bfloat16)
# tensor(1.5391, dtype=torch.bfloat16)
# tensor(0.5352, dtype=torch.bfloat16)
# tensor(4.8438, dtype=torch.bfloat16)
# tensor(1.9297, dtype=torch.bfloat16)
# tensor(0.4238, dtype=torch.bfloat16)
# tensor(0.4473, dtype=torch.bfloat16)
# tensor(0.6953, dtype=torch.bfloat16)
# tensor(5.6562, dtype=torch.bfloat16)
# tensor(5.7812, dtype=torch.bfloat16)
# tensor(0.3262, dtype=torch.bfloat16)
# tensor(1.3047, dtype=torch.bfloat16)
# tensor(0.6367, dtype=torch.bfloat16)
# tensor(7.1875, dtype=torch.bfloat16)
# tensor(3.2344, dtype=torch.bfloat16)
# tensor(3.8281, dtype=torch.bfloat16)
# tensor(78., dtype=torch.bfloat16)
# tensor(5.5625, dtype=torch.bfloat16)
# tensor(38.7500, dtype=torch.bfloat16)
# tensor(8.8750, dtype=torch.bfloat16)
# tensor(4.4375, dtype=torch.bfloat16)
# tensor(42.7500, dtype=torch.bfloat16)
# tensor(1.2188, dtype=torch.bfloat16)
# tensor(15.1250, dtype=torch.bfloat16)
# tensor(6.2188, dtype=torch.bfloat16)
# tensor(4.2812, dtype=torch.bfloat16)
# tensor(0.3457, dtype=torch.bfloat16)
# tensor(3.6562, dtype=torch.bfloat16)
# tensor(0.3496, dtype=torch.bfloat16)
# tensor(2.7969, dtype=torch.bfloat16)
# tensor(1.2734, dtype=torch.bfloat16)
# tensor(1.7344, dtype=torch.bfloat16)
# tensor(1.1797, dtype=torch.bfloat16)
# tensor(1.0703, dtype=torch.bfloat16)
# tensor(1.1328, dtype=torch.bfloat16)
# tensor(5.5312, dtype=torch.bfloat16)
# tensor(0.8984, dtype=torch.bfloat16)
# tensor(8.9375, dtype=torch.bfloat16)
# tensor(1.4844, dtype=torch.bfloat16)
# tensor(2.0156, dtype=torch.bfloat16)
# tensor(1.5312, dtype=torch.bfloat16)
# tensor(1.5078, dtype=torch.bfloat16)
# tensor(0.6836, dtype=torch.bfloat16)
# tensor(11.6250, dtype=torch.bfloat16)
# tensor(2.2188, dtype=torch.bfloat16)
# tensor(2.7500, dtype=torch.bfloat16)
# tensor(0.3965, dtype=torch.bfloat16)
# tensor(25.6250, dtype=torch.bfloat16)
# tensor(4.8125, dtype=torch.bfloat16)
# tensor(30.7500, dtype=torch.bfloat16)
# tensor(1.7109, dtype=torch.bfloat16)
# tensor(7.3438, dtype=torch.bfloat16)
# tensor(13.6875, dtype=torch.bfloat16)
# tensor(7.8125, dtype=torch.bfloat16)
# tensor(1.4375, dtype=torch.bfloat16)
# tensor(3.0938, dtype=torch.bfloat16)
# tensor(0.7930, dtype=torch.bfloat16)
# tensor(5., dtype=torch.bfloat16)
# tensor(2.7031, dtype=torch.bfloat16)
# tensor(0.5352, dtype=torch.bfloat16)
# tensor(6.0625, dtype=torch.bfloat16)
# tensor(5.2812, dtype=torch.bfloat16)
# tensor(2.9531, dtype=torch.bfloat16)
# tensor(0.9023, dtype=torch.bfloat16)
# tensor(0.6250, dtype=torch.bfloat16)
# tensor(4.7188, dtype=torch.bfloat16)
# tensor(1.1797, dtype=torch.bfloat16)
# tensor(9.8750, dtype=torch.bfloat16)
# tensor(4.3438, dtype=torch.bfloat16)
# tensor(1.3594, dtype=torch.bfloat16)
# tensor(1.0156, dtype=torch.bfloat16)
# tensor(2.3438, dtype=torch.bfloat16)
# tensor(19.6250, dtype=torch.bfloat16)
# tensor(11.1875, dtype=torch.bfloat16)
# tensor(1.1250, dtype=torch.bfloat16)
# tensor(7.3438, dtype=torch.bfloat16)
# tensor(0.7305, dtype=torch.bfloat16)
# tensor(4.1562, dtype=torch.bfloat16)
# tensor(0.3379, dtype=torch.bfloat16)
# tensor(2.1875, dtype=torch.bfloat16)
# tensor(1.7656, dtype=torch.bfloat16)
# tensor(2.8281, dtype=torch.bfloat16)
# tensor(4.4688, dtype=torch.bfloat16)
# tensor(4.0938, dtype=torch.bfloat16)
# tensor(24.8750, dtype=torch.bfloat16)
# tensor(0.3535, dtype=torch.bfloat16)
# tensor(6.3750, dtype=torch.bfloat16)
# tensor(6.4688, dtype=torch.bfloat16)
# tensor(13.4375, dtype=torch.bfloat16)
# tensor(2.3125, dtype=torch.bfloat16)
# tensor(2.7188, dtype=torch.bfloat16)
# tensor(9.4375, dtype=torch.bfloat16)
# tensor(1.1719, dtype=torch.bfloat16)
# tensor(2.8906, dtype=torch.bfloat16)
# tensor(0.9414, dtype=torch.bfloat16)
# tensor(2.7656, dtype=torch.bfloat16)
# tensor(1.9297, dtype=torch.bfloat16)
# tensor(0.8750, dtype=torch.bfloat16)
# tensor(4.9062, dtype=torch.bfloat16)
# tensor(0.5586, dtype=torch.bfloat16)
# tensor(1.2266, dtype=torch.bfloat16)
# tensor(3.7812, dtype=torch.bfloat16)
# tensor(0.7812, dtype=torch.bfloat16)
# tensor(358., dtype=torch.bfloat16)
# tensor(5.7812, dtype=torch.bfloat16)
# tensor(2.6406, dtype=torch.bfloat16)
# tensor(0.5625, dtype=torch.bfloat16)
# tensor(0.6836, dtype=torch.bfloat16)
# tensor(0.7852, dtype=torch.bfloat16)
# tensor(1.7422, dtype=torch.bfloat16)
# tensor(1.3125, dtype=torch.bfloat16)
# tensor(2.1875, dtype=torch.bfloat16)
# tensor(16., dtype=torch.bfloat16)
# tensor(1.0312, dtype=torch.bfloat16)
# tensor(9., dtype=torch.bfloat16)
# tensor(5.9688, dtype=torch.bfloat16)
# tensor(4.3438, dtype=torch.bfloat16)
# tensor(14.4375, dtype=torch.bfloat16)
# tensor(1.6094, dtype=torch.bfloat16)
# tensor(2.4375, dtype=torch.bfloat16)
# tensor(8.3125, dtype=torch.bfloat16)
# tensor(5.2500, dtype=torch.bfloat16)
# tensor(3.4375, dtype=torch.bfloat16)
# tensor(2.5938, dtype=torch.bfloat16)
# tensor(1.3047, dtype=torch.bfloat16)
# tensor(14.3125, dtype=torch.bfloat16)
# tensor(17.5000, dtype=torch.bfloat16)
# tensor(1.1562, dtype=torch.bfloat16)
# tensor(0.2031, dtype=torch.bfloat16)
# tensor(1.7891, dtype=torch.bfloat16)
# tensor(9.3125, dtype=torch.bfloat16)
# tensor(5.4688, dtype=torch.bfloat16)
# tensor(2.2344, dtype=torch.bfloat16)
# tensor(5.0312, dtype=torch.bfloat16)
# tensor(0.4688, dtype=torch.bfloat16)
# tensor(1.0469, dtype=torch.bfloat16)
# tensor(2.8750, dtype=torch.bfloat16)
# tensor(3.5156, dtype=torch.bfloat16)
# tensor(1.2031, dtype=torch.bfloat16)
# tensor(0.8398, dtype=torch.bfloat16)
# tensor(3.8281, dtype=torch.bfloat16)
# tensor(1.0547, dtype=torch.bfloat16)
# tensor(2.9531, dtype=torch.bfloat16)
# tensor(1.3984, dtype=torch.bfloat16)
# tensor(3.3125, dtype=torch.bfloat16)
# tensor(1.3984, dtype=torch.bfloat16)
# tensor(1.2656, dtype=torch.bfloat16)
# tensor(3.6719, dtype=torch.bfloat16)
# tensor(1.4375, dtype=torch.bfloat16)
# tensor(0.4219, dtype=torch.bfloat16)
# tensor(2.2656, dtype=torch.bfloat16)
# tensor(2.5000, dtype=torch.bfloat16)
# tensor(19.3750, dtype=torch.bfloat16)
# tensor(2.7188, dtype=torch.bfloat16)
# tensor(5.8750, dtype=torch.bfloat16)
# tensor(2.0938, dtype=torch.bfloat16)
# tensor(16.6250, dtype=torch.bfloat16)
# tensor(10.1250, dtype=torch.bfloat16)
# tensor(2.8750, dtype=torch.bfloat16)
# tensor(5.3125, dtype=torch.bfloat16)
# tensor(2.7344, dtype=torch.bfloat16)
# tensor(2.3750, dtype=torch.bfloat16)
# tensor(2.9688, dtype=torch.bfloat16)
# tensor(7.4375, dtype=torch.bfloat16)
# tensor(3.5312, dtype=torch.bfloat16)
# tensor(0.3750, dtype=torch.bfloat16)
# tensor(2.0312, dtype=torch.bfloat16)
# tensor(2.8125, dtype=torch.bfloat16)
# tensor(5.5938, dtype=torch.bfloat16)
# tensor(9., dtype=torch.bfloat16)
# tensor(8.5000, dtype=torch.bfloat16)
# tensor(1.3125, dtype=torch.bfloat16)
# tensor(0.6562, dtype=torch.bfloat16)
# tensor(3.1250, dtype=torch.bfloat16)
# tensor(3.3594, dtype=torch.bfloat16)
# tensor(1.1328, dtype=torch.bfloat16)
# tensor(6.9062, dtype=torch.bfloat16)
# tensor(2.2031, dtype=torch.bfloat16)
# tensor(1.1172, dtype=torch.bfloat16)
# tensor(0.9570, dtype=torch.bfloat16)
# tensor(3888., dtype=torch.bfloat16)
# tensor(0.4551, dtype=torch.bfloat16)
# tensor(0.4121, dtype=torch.bfloat16)
# tensor(9.7500, dtype=torch.bfloat16)
# tensor(3.5625, dtype=torch.bfloat16)
# tensor(8.8125, dtype=torch.bfloat16)
# tensor(1.6250, dtype=torch.bfloat16)
# tensor(1.5078, dtype=torch.bfloat16)
# tensor(0.3477, dtype=torch.bfloat16)
# tensor(0.8633, dtype=torch.bfloat16)
# tensor(7.1562, dtype=torch.bfloat16)
# tensor(20.6250, dtype=torch.bfloat16)
# tensor(5.9688, dtype=torch.bfloat16)
# tensor(3., dtype=torch.bfloat16)
# tensor(13.3125, dtype=torch.bfloat16)
# tensor(33., dtype=torch.bfloat16)
# tensor(1.5938, dtype=torch.bfloat16)
# tensor(0.3926, dtype=torch.bfloat16)
# tensor(2.5938, dtype=torch.bfloat16)
# tensor(0.4531, dtype=torch.bfloat16)
# tensor(1.1328, dtype=torch.bfloat16)
# tensor(11.1875, dtype=torch.bfloat16)
# tensor(3.9062, dtype=torch.bfloat16)
# tensor(10.9375, dtype=torch.bfloat16)
# tensor(1.0078, dtype=torch.bfloat16)
# tensor(1.3906, dtype=torch.bfloat16)
# tensor(0.4609, dtype=torch.bfloat16)
# tensor(2.2500, dtype=torch.bfloat16)
# tensor(1.5781, dtype=torch.bfloat16)
# tensor(2.8125, dtype=torch.bfloat16)
# tensor(1.5156, dtype=torch.bfloat16)
# tensor(26.2500, dtype=torch.bfloat16)
# tensor(2.2656, dtype=torch.bfloat16)
# tensor(14.9375, dtype=torch.bfloat16)
# tensor(4.5000, dtype=torch.bfloat16)
# tensor(0.1943, dtype=torch.bfloat16)
# tensor(0.6836, dtype=torch.bfloat16)
# tensor(5.5625, dtype=torch.bfloat16)
# tensor(1.1562, dtype=torch.bfloat16)
# tensor(2.2500, dtype=torch.bfloat16)
# tensor(2.3594, dtype=torch.bfloat16)
# tensor(7.1562, dtype=torch.bfloat16)
# tensor(18., dtype=torch.bfloat16)
# tensor(8.1250, dtype=torch.bfloat16)
# tensor(0.7617, dtype=torch.bfloat16)
# tensor(23.6250, dtype=torch.bfloat16)
# tensor(3.6719, dtype=torch.bfloat16)
# tensor(0.5859, dtype=torch.bfloat16)
# tensor(0.5352, dtype=torch.bfloat16)
# tensor(3.8906, dtype=torch.bfloat16)
# tensor(0.2207, dtype=torch.bfloat16)
# tensor(0.7109, dtype=torch.bfloat16)
# tensor(4.5938, dtype=torch.bfloat16)
# tensor(3.0156, dtype=torch.bfloat16)
# tensor(5.8125, dtype=torch.bfloat16)
# tensor(10.1250, dtype=torch.bfloat16)
# tensor(6.0312, dtype=torch.bfloat16)
# tensor(1.4531, dtype=torch.bfloat16)
# tensor(1.1641, dtype=torch.bfloat16)
# tensor(2.5781, dtype=torch.bfloat16)
# tensor(1.3125, dtype=torch.bfloat16)
# tensor(14.2500, dtype=torch.bfloat16)
# tensor(9.0625, dtype=torch.bfloat16)
# tensor(0.6992, dtype=torch.bfloat16)
# tensor(8.4375, dtype=torch.bfloat16)
# tensor(1.5156, dtype=torch.bfloat16)
# tensor(78., dtype=torch.bfloat16)
# tensor(1.0703, dtype=torch.bfloat16)
# tensor(0.4785, dtype=torch.bfloat16)
# tensor(2.3438, dtype=torch.bfloat16)
# tensor(29.3750, dtype=torch.bfloat16)
# tensor(3.0938, dtype=torch.bfloat16)
# tensor(3.0312, dtype=torch.bfloat16)
# tensor(4.0625, dtype=torch.bfloat16)
# tensor(18.6250, dtype=torch.bfloat16)
# tensor(4.1562, dtype=torch.bfloat16)
# tensor(1.1719, dtype=torch.bfloat16)
# tensor(4.0312, dtype=torch.bfloat16)
# tensor(5.0625, dtype=torch.bfloat16)
# tensor(1.5391, dtype=torch.bfloat16)
# tensor(15.1875, dtype=torch.bfloat16)
# tensor(1.1484, dtype=torch.bfloat16)
# tensor(18.5000, dtype=torch.bfloat16)
# tensor(2.6406, dtype=torch.bfloat16)
# tensor(2.0625, dtype=torch.bfloat16)
# tensor(4.8438, dtype=torch.bfloat16)
# tensor(12.2500, dtype=torch.bfloat16)
# tensor(0.4727, dtype=torch.bfloat16)
# tensor(11.5000, dtype=torch.bfloat16)
# tensor(17.3750, dtype=torch.bfloat16)
# tensor(0.6289, dtype=torch.bfloat16)
# tensor(5.5000, dtype=torch.bfloat16)
# tensor(3.0312, dtype=torch.bfloat16)
# tensor(11.8125, dtype=torch.bfloat16)
# tensor(0.8242, dtype=torch.bfloat16)
# tensor(0.3320, dtype=torch.bfloat16)
# tensor(5.1562, dtype=torch.bfloat16)
# tensor(0.9180, dtype=torch.bfloat16)
# tensor(3.9688, dtype=torch.bfloat16)
# tensor(0.8438, dtype=torch.bfloat16)
# tensor(2.4531, dtype=torch.bfloat16)
# tensor(0.2812, dtype=torch.bfloat16)
# tensor(2.2031, dtype=torch.bfloat16)
# tensor(1.3906, dtype=torch.bfloat16)
# tensor(2.1250, dtype=torch.bfloat16)
# tensor(0.5898, dtype=torch.bfloat16)
# tensor(0.3809, dtype=torch.bfloat16)
# tensor(11.3750, dtype=torch.bfloat16)
# tensor(1.7734, dtype=torch.bfloat16)
# tensor(0.5078, dtype=torch.bfloat16)
# tensor(1.3281, dtype=torch.bfloat16)
# tensor(0.4941, dtype=torch.bfloat16)
# tensor(6.3750, dtype=torch.bfloat16)
# tensor(1.3516, dtype=torch.bfloat16)
# tensor(7.9375, dtype=torch.bfloat16)
# tensor(3.7969, dtype=torch.bfloat16)
# tensor(2.7656, dtype=torch.bfloat16)
# tensor(1.1953, dtype=torch.bfloat16)
# tensor(1.4766, dtype=torch.bfloat16)
# tensor(2.0312, dtype=torch.bfloat16)
# tensor(0.2539, dtype=torch.bfloat16)
# tensor(0.6055, dtype=torch.bfloat16)
# tensor(2.8125, dtype=torch.bfloat16)
# tensor(0.6523, dtype=torch.bfloat16)
# tensor(2.1875, dtype=torch.bfloat16)
# tensor(10.5625, dtype=torch.bfloat16)
# tensor(5.2188, dtype=torch.bfloat16)
# tensor(2.5156, dtype=torch.bfloat16)
# tensor(14.8125, dtype=torch.bfloat16)
# tensor(2.2812, dtype=torch.bfloat16)
# tensor(6.2812, dtype=torch.bfloat16)
# tensor(0.7070, dtype=torch.bfloat16)
# tensor(0.6719, dtype=torch.bfloat16)
# tensor(1.2578, dtype=torch.bfloat16)
# tensor(4.0312, dtype=torch.bfloat16)
# tensor(0.2695, dtype=torch.bfloat16)
# tensor(3.2812, dtype=torch.bfloat16)
# tensor(3.1406, dtype=torch.bfloat16)
# tensor(2.6562, dtype=torch.bfloat16)
# tensor(1.0078, dtype=torch.bfloat16)
# tensor(0.9961, dtype=torch.bfloat16)
# tensor(2.8906, dtype=torch.bfloat16)
# tensor(2.2344, dtype=torch.bfloat16)
# tensor(4.6875, dtype=torch.bfloat16)
# tensor(55.5000, dtype=torch.bfloat16)
# tensor(0.4980, dtype=torch.bfloat16)
# tensor(4.5938, dtype=torch.bfloat16)
# tensor(1.0391, dtype=torch.bfloat16)
# tensor(1., dtype=torch.bfloat16)
# tensor(1.5078, dtype=torch.bfloat16)
# tensor(6.3125, dtype=torch.bfloat16)
# tensor(8.8125, dtype=torch.bfloat16)
# tensor(6.1562, dtype=torch.bfloat16)
# tensor(0.8047, dtype=torch.bfloat16)
# tensor(4.5000, dtype=torch.bfloat16)
# tensor(3.7031, dtype=torch.bfloat16)
# tensor(5.5000, dtype=torch.bfloat16)
# tensor(3.9844, dtype=torch.bfloat16)
# tensor(4.8750, dtype=torch.bfloat16)
# tensor(9.6250, dtype=torch.bfloat16)
# tensor(1.4922, dtype=torch.bfloat16)
# tensor(2.8906, dtype=torch.bfloat16)
# tensor(1.6094, dtype=torch.bfloat16)
# tensor(9.9375, dtype=torch.bfloat16)
# tensor(2.4531, dtype=torch.bfloat16)
# tensor(3.0469, dtype=torch.bfloat16)
# tensor(5., dtype=torch.bfloat16)
# tensor(8.0625, dtype=torch.bfloat16)
# tensor(0.5430, dtype=torch.bfloat16)
# tensor(0.3906, dtype=torch.bfloat16)
# tensor(2.9062, dtype=torch.bfloat16)
# tensor(2.0312, dtype=torch.bfloat16)
# tensor(0.5625, dtype=torch.bfloat16)
# tensor(1.1406, dtype=torch.bfloat16)
# tensor(0.9297, dtype=torch.bfloat16)
# tensor(13.5000, dtype=torch.bfloat16)
# tensor(0.1787, dtype=torch.bfloat16)
# tensor(4.7500, dtype=torch.bfloat16)
# tensor(0.4746, dtype=torch.bfloat16)
# tensor(0.2334, dtype=torch.bfloat16)
# tensor(6.0938, dtype=torch.bfloat16)
# tensor(0.1748, dtype=torch.bfloat16)
# tensor(1.3047, dtype=torch.bfloat16)
# tensor(1.2656, dtype=torch.bfloat16)
# tensor(7.7188, dtype=torch.bfloat16)
# tensor(1.4766, dtype=torch.bfloat16)
# tensor(0.8945, dtype=torch.bfloat16)
# tensor(1.4766, dtype=torch.bfloat16)
# tensor(1.1953, dtype=torch.bfloat16)
# tensor(10.8125, dtype=torch.bfloat16)
# tensor(2.7031, dtype=torch.bfloat16)
# tensor(58.5000, dtype=torch.bfloat16)
# tensor(2.2969, dtype=torch.bfloat16)
# tensor(0.6992, dtype=torch.bfloat16)
# tensor(0.9336, dtype=torch.bfloat16)
# tensor(11.5625, dtype=torch.bfloat16)
# tensor(10.7500, dtype=torch.bfloat16)
# tensor(10.3750, dtype=torch.bfloat16)
# tensor(1.5000, dtype=torch.bfloat16)
# tensor(0.7461, dtype=torch.bfloat16)
# tensor(5., dtype=torch.bfloat16)
# tensor(6.3750, dtype=torch.bfloat16)
# tensor(3.0312, dtype=torch.bfloat16)
# tensor(1.2188, dtype=torch.bfloat16)
# tensor(17., dtype=torch.bfloat16)
# tensor(16., dtype=torch.bfloat16)
# tensor(15.2500, dtype=torch.bfloat16)
# tensor(0.4531, dtype=torch.bfloat16)
# tensor(0.6562, dtype=torch.bfloat16)
# tensor(2.9688, dtype=torch.bfloat16)
# tensor(4.0625, dtype=torch.bfloat16)
# tensor(1.0859, dtype=torch.bfloat16)
# tensor(3.6406, dtype=torch.bfloat16)
# tensor(12.8125, dtype=torch.bfloat16)
# tensor(3., dtype=torch.bfloat16)
# tensor(3.8750, dtype=torch.bfloat16)
# tensor(2.6719, dtype=torch.bfloat16)
# tensor(15.2500, dtype=torch.bfloat16)
# tensor(6.4062, dtype=torch.bfloat16)
# tensor(10.3125, dtype=torch.bfloat16)
# tensor(0.3652, dtype=torch.bfloat16)
# tensor(4.1250, dtype=torch.bfloat16)
# tensor(2.9844, dtype=torch.bfloat16)
# tensor(0.3027, dtype=torch.bfloat16)
# tensor(1.7969, dtype=torch.bfloat16)
# tensor(0.3848, dtype=torch.bfloat16)
# tensor(5.4375, dtype=torch.bfloat16)
# tensor(1.4297, dtype=torch.bfloat16)
# tensor(0.4219, dtype=torch.bfloat16)
# tensor(1.1953, dtype=torch.bfloat16)
# tensor(7.1250, dtype=torch.bfloat16)
# tensor(7.0625, dtype=torch.bfloat16)
# tensor(4.7188, dtype=torch.bfloat16)
# tensor(3.1094, dtype=torch.bfloat16)
# tensor(4.9375, dtype=torch.bfloat16)
# tensor(6.8750, dtype=torch.bfloat16)
# tensor(2.5156, dtype=torch.bfloat16)
# tensor(5.6250, dtype=torch.bfloat16)
# tensor(1.2578, dtype=torch.bfloat16)
# tensor(28928., dtype=torch.bfloat16)
# tensor(0.3672, dtype=torch.bfloat16)
# tensor(2.4531, dtype=torch.bfloat16)
# tensor(3.2812, dtype=torch.bfloat16)
# tensor(1.1172, dtype=torch.bfloat16)
# tensor(5.8750, dtype=torch.bfloat16)
# tensor(60.7500, dtype=torch.bfloat16)
# tensor(2.5625, dtype=torch.bfloat16)
# tensor(0.9141, dtype=torch.bfloat16)
# tensor(1.1953, dtype=torch.bfloat16)
# tensor(4.2188, dtype=torch.bfloat16)
# tensor(0.4219, dtype=torch.bfloat16)
# tensor(9.3125, dtype=torch.bfloat16)
# tensor(4.8438, dtype=torch.bfloat16)
# tensor(2.0625, dtype=torch.bfloat16)
# tensor(5.3438, dtype=torch.bfloat16)
# tensor(4.4375, dtype=torch.bfloat16)
# tensor(1.7344, dtype=torch.bfloat16)
# tensor(4.8125, dtype=torch.bfloat16)
# tensor(13., dtype=torch.bfloat16)
# tensor(5.0625, dtype=torch.bfloat16)
# tensor(2.2969, dtype=torch.bfloat16)
# tensor(7.9688, dtype=torch.bfloat16)
# tensor(4.5312, dtype=torch.bfloat16)
# tensor(2.8594, dtype=torch.bfloat16)
# tensor(0.2754, dtype=torch.bfloat16)
# tensor(0.2578, dtype=torch.bfloat16)
# tensor(0.7930, dtype=torch.bfloat16)
# tensor(5.4062, dtype=torch.bfloat16)
# tensor(7.8438, dtype=torch.bfloat16)
# tensor(9.6875, dtype=torch.bfloat16)
# tensor(23.7500, dtype=torch.bfloat16)
# tensor(1.2500, dtype=torch.bfloat16)
# tensor(0.7500, dtype=torch.bfloat16)
# tensor(5.8750, dtype=torch.bfloat16)
# tensor(1.8047, dtype=torch.bfloat16)
# tensor(2.1719, dtype=torch.bfloat16)
# tensor(0.2988, dtype=torch.bfloat16)
# tensor(0.4551, dtype=torch.bfloat16)
# tensor(1.4531, dtype=torch.bfloat16)
# tensor(3.7969, dtype=torch.bfloat16)
# tensor(0.5273, dtype=torch.bfloat16)
# tensor(2.0938, dtype=torch.bfloat16)
# tensor(3.0938, dtype=torch.bfloat16)
# tensor(0.7773, dtype=torch.bfloat16)
# tensor(0.5156, dtype=torch.bfloat16)
# tensor(3.1094, dtype=torch.bfloat16)
# tensor(0.9258, dtype=torch.bfloat16)
# tensor(2.0625, dtype=torch.bfloat16)
# tensor(0.7969, dtype=torch.bfloat16)
# tensor(4.7500, dtype=torch.bfloat16)
# tensor(9.0625, dtype=torch.bfloat16)
# tensor(2.3125, dtype=torch.bfloat16)
# tensor(0.4746, dtype=torch.bfloat16)
# tensor(1.9219, dtype=torch.bfloat16)
# tensor(11.1875, dtype=torch.bfloat16)
# tensor(0.2080, dtype=torch.bfloat16)
# tensor(1.0078, dtype=torch.bfloat16)
# tensor(45056., dtype=torch.bfloat16)
# tensor(2.8438, dtype=torch.bfloat16)
# tensor(5.9062, dtype=torch.bfloat16)
# tensor(2.7969, dtype=torch.bfloat16)
# tensor(0.6797, dtype=torch.bfloat16)
# tensor(3.3750, dtype=torch.bfloat16)
# tensor(0.8789, dtype=torch.bfloat16)
# tensor(2.3750, dtype=torch.bfloat16)
# tensor(3.3125, dtype=torch.bfloat16)
# tensor(5.7500, dtype=torch.bfloat16)
# tensor(9.5625, dtype=torch.bfloat16)
# tensor(3.5625, dtype=torch.bfloat16)
# tensor(6.5312, dtype=torch.bfloat16)
# tensor(1.0938, dtype=torch.bfloat16)
# tensor(5.6562, dtype=torch.bfloat16)
# tensor(0.4902, dtype=torch.bfloat16)
# tensor(0.2334, dtype=torch.bfloat16)
# tensor(5.1875, dtype=torch.bfloat16)
# tensor(5.2188, dtype=torch.bfloat16)
# tensor(4.8750, dtype=torch.bfloat16)
# tensor(10.0625, dtype=torch.bfloat16)
# tensor(10.6875, dtype=torch.bfloat16)
# tensor(3.7656, dtype=torch.bfloat16)
# tensor(1.1953, dtype=torch.bfloat16)
# tensor(4.4062, dtype=torch.bfloat16)
# tensor(2.8750, dtype=torch.bfloat16)
# tensor(2.6719, dtype=torch.bfloat16)
# tensor(1.2422, dtype=torch.bfloat16)
# tensor(1.7812, dtype=torch.bfloat16)
# tensor(1.4141, dtype=torch.bfloat16)
# tensor(2.2500, dtype=torch.bfloat16)
# tensor(5.1562, dtype=torch.bfloat16)
# tensor(1.4531, dtype=torch.bfloat16)
# tensor(2.3906, dtype=torch.bfloat16)
# tensor(1.2500, dtype=torch.bfloat16)
# tensor(2.5781, dtype=torch.bfloat16)
# tensor(5.6562, dtype=torch.bfloat16)
# tensor(1.1562, dtype=torch.bfloat16)
# tensor(1.0547, dtype=torch.bfloat16)
# tensor(0.8750, dtype=torch.bfloat16)
# tensor(1.3750, dtype=torch.bfloat16)
# tensor(2.5781, dtype=torch.bfloat16)
# tensor(1.4375, dtype=torch.bfloat16)
# tensor(4.2812, dtype=torch.bfloat16)
# tensor(3.5469, dtype=torch.bfloat16)
# tensor(10.1250, dtype=torch.bfloat16)
# tensor(4.3125, dtype=torch.bfloat16)
# tensor(8.6250, dtype=torch.bfloat16)
# tensor(10.1875, dtype=torch.bfloat16)
# tensor(5.5000, dtype=torch.bfloat16)
# tensor(4.0625, dtype=torch.bfloat16)
# tensor(2.7500, dtype=torch.bfloat16)
# tensor(3.7344, dtype=torch.bfloat16)
# tensor(4.0312, dtype=torch.bfloat16)
# tensor(2.7969, dtype=torch.bfloat16)
# tensor(1.2734, dtype=torch.bfloat16)
# tensor(4.0938, dtype=torch.bfloat16)
# tensor(3.6719, dtype=torch.bfloat16)
# tensor(3.0781, dtype=torch.bfloat16)
# tensor(1.6016, dtype=torch.bfloat16)
# tensor(8.8125, dtype=torch.bfloat16)
# tensor(5.4688, dtype=torch.bfloat16)
# tensor(0.4473, dtype=torch.bfloat16)
# tensor(0.4941, dtype=torch.bfloat16)
# tensor(0.9258, dtype=torch.bfloat16)
# tensor(4.5000, dtype=torch.bfloat16)
# tensor(9.3125, dtype=torch.bfloat16)
# tensor(3.5625, dtype=torch.bfloat16)
# tensor(0.5664, dtype=torch.bfloat16)
# tensor(1800., dtype=torch.bfloat16)
# tensor(8.9375, dtype=torch.bfloat16)
# tensor(1.6016, dtype=torch.bfloat16)
# tensor(0.3066, dtype=torch.bfloat16)
# tensor(0.9453, dtype=torch.bfloat16)
# tensor(20.1250, dtype=torch.bfloat16)
# tensor(10.8125, dtype=torch.bfloat16)
# tensor(3., dtype=torch.bfloat16)
# tensor(4.1250, dtype=torch.bfloat16)
# tensor(5., dtype=torch.bfloat16)
# tensor(5.5938, dtype=torch.bfloat16)
# tensor(2.4375, dtype=torch.bfloat16)
# tensor(2.3281, dtype=torch.bfloat16)
# tensor(1.5938, dtype=torch.bfloat16)
# tensor(1.3906, dtype=torch.bfloat16)
# tensor(4.4375, dtype=torch.bfloat16)
# tensor(7.8750, dtype=torch.bfloat16)
# tensor(5.3438, dtype=torch.bfloat16)
# tensor(3.6562, dtype=torch.bfloat16)
# tensor(3.3125, dtype=torch.bfloat16)
# tensor(504., dtype=torch.bfloat16)
# tensor(3.7344, dtype=torch.bfloat16)
# tensor(0.5977, dtype=torch.bfloat16)
# tensor(2.3906, dtype=torch.bfloat16)
# tensor(16.7500, dtype=torch.bfloat16)
# tensor(0.3301, dtype=torch.bfloat16)
# tensor(0.6875, dtype=torch.bfloat16)
# tensor(1.6484, dtype=torch.bfloat16)
# tensor(15.2500, dtype=torch.bfloat16)
# tensor(1.3828, dtype=torch.bfloat16)
# tensor(4.6250, dtype=torch.bfloat16)
# tensor(0.2852, dtype=torch.bfloat16)
# tensor(0.2178, dtype=torch.bfloat16)
# tensor(5.6562, dtype=torch.bfloat16)
# tensor(1.2812, dtype=torch.bfloat16)
# tensor(0.9453, dtype=torch.bfloat16)
# ...
# tensor(3.6406, dtype=torch.bfloat16)
# tensor(1.3438, dtype=torch.bfloat16)
# tensor(7.1875, dtype=torch.bfloat16)
# tensor(2.5469, dtype=torch.bfloat16)
# tensor(7.5000, dtype=torch.bfloat16)
# tensor(0.3984, dtype=torch.bfloat16)
# tensor(2.0156, dtype=torch.bfloat16)
# tensor(0.5859, dtype=torch.bfloat16)
# tensor(0.2119, dtype=torch.bfloat16)
# tensor(10.1875, dtype=torch.bfloat16)
# tensor(0.2910, dtype=torch.bfloat16)
# tensor(2.4219, dtype=torch.bfloat16)
# tensor(1.5391, dtype=torch.bfloat16)
# tensor(3.1562, dtype=torch.bfloat16)
# tensor(2.9219, dtype=torch.bfloat16)
# tensor(4.5000, dtype=torch.bfloat16)
# tensor(6.7188, dtype=torch.bfloat16)
# tensor(1.2734, dtype=torch.bfloat16)
# tensor(3.5625, dtype=torch.bfloat16)
# tensor(0.5820, dtype=torch.bfloat16)
# tensor(1.1797, dtype=torch.bfloat16)
# tensor(2.3125, dtype=torch.bfloat16)
# tensor(0.7734, dtype=torch.bfloat16)
# tensor(1.3984, dtype=torch.bfloat16)
# tensor(8.9375, dtype=torch.bfloat16)
# tensor(5.5938, dtype=torch.bfloat16)
# tensor(1.1875, dtype=torch.bfloat16)
# tensor(0.9688, dtype=torch.bfloat16)
# tensor(1.1484, dtype=torch.bfloat16)
# tensor(2.5625, dtype=torch.bfloat16)
# tensor(1.3047, dtype=torch.bfloat16)
# tensor(5.3125, dtype=torch.bfloat16)
# tensor(3.9844, dtype=torch.bfloat16)
# tensor(1.8438, dtype=torch.bfloat16)
# tensor(0.4473, dtype=torch.bfloat16)
# tensor(3.2500, dtype=torch.bfloat16)
# tensor(1.9922, dtype=torch.bfloat16)
# tensor(16.1250, dtype=torch.bfloat16)
# tensor(1.4531, dtype=torch.bfloat16)
# tensor(2.2969, dtype=torch.bfloat16)
# tensor(0.5977, dtype=torch.bfloat16)
# tensor(3.9375, dtype=torch.bfloat16)
# tensor(1.8438, dtype=torch.bfloat16)
# tensor(2.9219, dtype=torch.bfloat16)
# tensor(11.3750, dtype=torch.bfloat16)
# tensor(3.3594, dtype=torch.bfloat16)
# tensor(5.1250, dtype=torch.bfloat16)
# tensor(0.7109, dtype=torch.bfloat16)
# tensor(3.3906, dtype=torch.bfloat16)
# tensor(8.3125, dtype=torch.bfloat16)
# tensor(6.8125, dtype=torch.bfloat16)
# tensor(0.7617, dtype=torch.bfloat16)
# tensor(24.8750, dtype=torch.bfloat16)
# tensor(12.3125, dtype=torch.bfloat16)
# tensor(0.3535, dtype=torch.bfloat16)
# tensor(2.9688, dtype=torch.bfloat16)
# tensor(7.7500, dtype=torch.bfloat16)
# tensor(0.8086, dtype=torch.bfloat16)
# tensor(7.1875, dtype=torch.bfloat16)
# tensor(18.8750, dtype=torch.bfloat16)
# tensor(18., dtype=torch.bfloat16)
# tensor(4.9062, dtype=torch.bfloat16)
# tensor(5.2812, dtype=torch.bfloat16)
# tensor(0.7852, dtype=torch.bfloat16)
# tensor(2.2031, dtype=torch.bfloat16)
# tensor(12.6250, dtype=torch.bfloat16)
# tensor(4.4062, dtype=torch.bfloat16)
# tensor(1.2656, dtype=torch.bfloat16)
# tensor(2.9844, dtype=torch.bfloat16)
# tensor(5.1250, dtype=torch.bfloat16)
# tensor(4.0938, dtype=torch.bfloat16)
# tensor(6.1250, dtype=torch.bfloat16)
# tensor(3.9531, dtype=torch.bfloat16)
# tensor(0.8828, dtype=torch.bfloat16)
# tensor(13.5000, dtype=torch.bfloat16)
# tensor(1.3672, dtype=torch.bfloat16)
# tensor(3.0312, dtype=torch.bfloat16)
# tensor(1.9375, dtype=torch.bfloat16)
# tensor(1.0234, dtype=torch.bfloat16)
# tensor(7.7188, dtype=torch.bfloat16)
# tensor(0.4668, dtype=torch.bfloat16)
# tensor(0.9258, dtype=torch.bfloat16)
# tensor(5.0625, dtype=torch.bfloat16)
# tensor(0.1836, dtype=torch.bfloat16)
# tensor(1.1562, dtype=torch.bfloat16)
# tensor(4.5938, dtype=torch.bfloat16)
# tensor(0.1709, dtype=torch.bfloat16)
# tensor(23.3750, dtype=torch.bfloat16)
# tensor(1.3281, dtype=torch.bfloat16)
# tensor(1.7812, dtype=torch.bfloat16)
# tensor(0.8164, dtype=torch.bfloat16)
# tensor(1.2578, dtype=torch.bfloat16)
# tensor(2.0469, dtype=torch.bfloat16)
# tensor(1.6406, dtype=torch.bfloat16)
# tensor(6.2500, dtype=torch.bfloat16)
# tensor(0.4199, dtype=torch.bfloat16)
# tensor(0.3398, dtype=torch.bfloat16)
# tensor(0.5938, dtype=torch.bfloat16)
# tensor(7.4688, dtype=torch.bfloat16)
# tensor(0.6914, dtype=torch.bfloat16)
# tensor(1.8516, dtype=torch.bfloat16)
# tensor(4.4688, dtype=torch.bfloat16)
# tensor(3.9062, dtype=torch.bfloat16)
# tensor(1.1953, dtype=torch.bfloat16)
# tensor(0.2773, dtype=torch.bfloat16)
# tensor(2.2812, dtype=torch.bfloat16)
# tensor(2.7344, dtype=torch.bfloat16)
# tensor(0.3613, dtype=torch.bfloat16)
# tensor(0.4844, dtype=torch.bfloat16)
# tensor(4.7812, dtype=torch.bfloat16)
# tensor(1.4297, dtype=torch.bfloat16)
# tensor(1.8281, dtype=torch.bfloat16)
# tensor(0.8320, dtype=torch.bfloat16)
# tensor(2.2344, dtype=torch.bfloat16)
# tensor(0.2363, dtype=torch.bfloat16)
# tensor(5.3750, dtype=torch.bfloat16)
# tensor(7.3438, dtype=torch.bfloat16)
# tensor(1.6016, dtype=torch.bfloat16)
# tensor(0.8594, dtype=torch.bfloat16)
# tensor(0.4844, dtype=torch.bfloat16)
# tensor(1.2188, dtype=torch.bfloat16)
# tensor(8.6875, dtype=torch.bfloat16)
# tensor(10.9375, dtype=torch.bfloat16)
# tensor(3.6562, dtype=torch.bfloat16)
# tensor(4.5625, dtype=torch.bfloat16)
# tensor(9.6875, dtype=torch.bfloat16)
# tensor(6.7188, dtype=torch.bfloat16)
# tensor(16., dtype=torch.bfloat16)
# tensor(2.4844, dtype=torch.bfloat16)
# tensor(5.6562, dtype=torch.bfloat16)
# tensor(5.6875, dtype=torch.bfloat16)
# tensor(1.5234, dtype=torch.bfloat16)
# tensor(1.5234, dtype=torch.bfloat16)
# tensor(2.5312, dtype=torch.bfloat16)
# tensor(7.1875, dtype=torch.bfloat16)
# tensor(2.1094, dtype=torch.bfloat16)
# tensor(6.5000, dtype=torch.bfloat16)
# tensor(1.4844, dtype=torch.bfloat16)
# tensor(10., dtype=torch.bfloat16)
# tensor(0.9336, dtype=torch.bfloat16)
# tensor(3.0625, dtype=torch.bfloat16)
# tensor(5.9375, dtype=torch.bfloat16)
# tensor(1.6953, dtype=torch.bfloat16)
# tensor(10.6250, dtype=torch.bfloat16)
# tensor(11.6250, dtype=torch.bfloat16)
# tensor(0.7695, dtype=torch.bfloat16)
# tensor(2.5156, dtype=torch.bfloat16)
# tensor(2.5938, dtype=torch.bfloat16)
# tensor(2.2188, dtype=torch.bfloat16)
# tensor(0.7031, dtype=torch.bfloat16)
# tensor(0.6914, dtype=torch.bfloat16)
# tensor(11.8750, dtype=torch.bfloat16)
# tensor(2.7500, dtype=torch.bfloat16)
# tensor(9.3125, dtype=torch.bfloat16)
# tensor(23.5000, dtype=torch.bfloat16)
# tensor(0.1904, dtype=torch.bfloat16)
# tensor(1.7422, dtype=torch.bfloat16)
# tensor(5.3125, dtype=torch.bfloat16)
# tensor(10.8750, dtype=torch.bfloat16)
# tensor(1.0312, dtype=torch.bfloat16)
# tensor(0.5703, dtype=torch.bfloat16)
# tensor(9.6875, dtype=torch.bfloat16)
# tensor(9.8125, dtype=torch.bfloat16)
# tensor(0.9922, dtype=torch.bfloat16)
# tensor(1.5859, dtype=torch.bfloat16)
# tensor(11.5625, dtype=torch.bfloat16)
# tensor(0.4199, dtype=torch.bfloat16)
# tensor(0.3555, dtype=torch.bfloat16)
# tensor(3.0938, dtype=torch.bfloat16)
# tensor(1.0859, dtype=torch.bfloat16)
# tensor(0.4316, dtype=torch.bfloat16)
# tensor(10.0625, dtype=torch.bfloat16)
# tensor(1.2188, dtype=torch.bfloat16)
# tensor(1.6406, dtype=torch.bfloat16)
# tensor(9.2500, dtype=torch.bfloat16)
# tensor(0.8477, dtype=torch.bfloat16)
# tensor(1.8594, dtype=torch.bfloat16)
# tensor(6.1250, dtype=torch.bfloat16)
# tensor(2.4219, dtype=torch.bfloat16)
# tensor(8.7500, dtype=torch.bfloat16)
# tensor(1.2734, dtype=torch.bfloat16)
# tensor(1.0312, dtype=torch.bfloat16)
# tensor(0.8164, dtype=torch.bfloat16)
# tensor(0.4570, dtype=torch.bfloat16)
# tensor(1.3203, dtype=torch.bfloat16)
# tensor(0.7305, dtype=torch.bfloat16)
# tensor(0.6602, dtype=torch.bfloat16)
# tensor(0.3652, dtype=torch.bfloat16)
# tensor(1.9375, dtype=torch.bfloat16)
# tensor(3.2656, dtype=torch.bfloat16)
# tensor(10.3125, dtype=torch.bfloat16)
# tensor(2.0156, dtype=torch.bfloat16)
# tensor(6.8125, dtype=torch.bfloat16)
# tensor(1.9219, dtype=torch.bfloat16)
# tensor(3.1094, dtype=torch.bfloat16)
# tensor(11.6250, dtype=torch.bfloat16)
# tensor(0.7578, dtype=torch.bfloat16)
# tensor(0.4707, dtype=torch.bfloat16)
# tensor(4.2500, dtype=torch.bfloat16)
# tensor(0.3730, dtype=torch.bfloat16)
# tensor(8.2500, dtype=torch.bfloat16)
# tensor(0.2334, dtype=torch.bfloat16)
# tensor(3.2656, dtype=torch.bfloat16)
# tensor(9.4375, dtype=torch.bfloat16)
# tensor(22.3750, dtype=torch.bfloat16)
# tensor(18.5000, dtype=torch.bfloat16)
# tensor(0.4277, dtype=torch.bfloat16)
# tensor(19.3750, dtype=torch.bfloat16)
# tensor(0.7422, dtype=torch.bfloat16)
# tensor(10., dtype=torch.bfloat16)
# tensor(0.3398, dtype=torch.bfloat16)
# tensor(5.2188, dtype=torch.bfloat16)
# tensor(1.0156, dtype=torch.bfloat16)
# tensor(7.2812, dtype=torch.bfloat16)
# tensor(11.5625, dtype=torch.bfloat16)
# tensor(3.1719, dtype=torch.bfloat16)
# tensor(2.9062, dtype=torch.bfloat16)
# tensor(0.9453, dtype=torch.bfloat16)
# tensor(4.1562, dtype=torch.bfloat16)
# tensor(0.5273, dtype=torch.bfloat16)
# tensor(0.2373, dtype=torch.bfloat16)
# tensor(0.2812, dtype=torch.bfloat16)
# tensor(5.1250, dtype=torch.bfloat16)
# tensor(6.0938, dtype=torch.bfloat16)
# tensor(4.1562, dtype=torch.bfloat16)
# tensor(3.0312, dtype=torch.bfloat16)
# tensor(2.8594, dtype=torch.bfloat16)
# tensor(3.0469, dtype=torch.bfloat16)
# tensor(0.4707, dtype=torch.bfloat16)
# tensor(0.6055, dtype=torch.bfloat16)
# tensor(2.7344, dtype=torch.bfloat16)
# tensor(0.3730, dtype=torch.bfloat16)
# tensor(1.2969, dtype=torch.bfloat16)
# tensor(14.9375, dtype=torch.bfloat16)
# tensor(1.4453, dtype=torch.bfloat16)
# tensor(5.6250, dtype=torch.bfloat16)
# tensor(4.5312, dtype=torch.bfloat16)
# tensor(4.9375, dtype=torch.bfloat16)
# tensor(1.4766, dtype=torch.bfloat16)
# tensor(5.1875, dtype=torch.bfloat16)
# tensor(6.0625, dtype=torch.bfloat16)
# tensor(2.9688, dtype=torch.bfloat16)
# tensor(5.8438, dtype=torch.bfloat16)
# tensor(5.6875, dtype=torch.bfloat16)
# tensor(1.1094, dtype=torch.bfloat16)
# tensor(3.0156, dtype=torch.bfloat16)
# tensor(5.6562, dtype=torch.bfloat16)
# tensor(2.8594, dtype=torch.bfloat16)
# tensor(2.5781, dtype=torch.bfloat16)
# tensor(0.7539, dtype=torch.bfloat16)
# tensor(6.2188, dtype=torch.bfloat16)
# tensor(2.9375, dtype=torch.bfloat16)
# tensor(1.2656, dtype=torch.bfloat16)
# tensor(2.0625, dtype=torch.bfloat16)
# tensor(1.4219, dtype=torch.bfloat16)
# tensor(0.7773, dtype=torch.bfloat16)
# tensor(0.2871, dtype=torch.bfloat16)
# tensor(15.4375, dtype=torch.bfloat16)
# tensor(0.6094, dtype=torch.bfloat16)
# tensor(2.2344, dtype=torch.bfloat16)
# tensor(2.6406, dtype=torch.bfloat16)
# tensor(0.8555, dtype=torch.bfloat16)
# tensor(2.9219, dtype=torch.bfloat16)
# tensor(6.5312, dtype=torch.bfloat16)
# tensor(0.3184, dtype=torch.bfloat16)
# tensor(0.9648, dtype=torch.bfloat16)
# tensor(9.3750, dtype=torch.bfloat16)
# tensor(0.3730, dtype=torch.bfloat16)
# tensor(13.5000, dtype=torch.bfloat16)
# tensor(6.4688, dtype=torch.bfloat16)
# tensor(7.8125, dtype=torch.bfloat16)
# tensor(0.2949, dtype=torch.bfloat16)
# tensor(15.7500, dtype=torch.bfloat16)
# tensor(3.1250, dtype=torch.bfloat16)
# tensor(65., dtype=torch.bfloat16)
# tensor(2.7812, dtype=torch.bfloat16)
# tensor(4.1250, dtype=torch.bfloat16)
# tensor(2.4062, dtype=torch.bfloat16)
# tensor(8.8125, dtype=torch.bfloat16)
# tensor(0.7578, dtype=torch.bfloat16)
# tensor(1.1562, dtype=torch.bfloat16)
# tensor(17., dtype=torch.bfloat16)
# tensor(3.8438, dtype=torch.bfloat16)
# tensor(10.8125, dtype=torch.bfloat16)
# tensor(11.5625, dtype=torch.bfloat16)
# tensor(2.8438, dtype=torch.bfloat16)
# tensor(2.7812, dtype=torch.bfloat16)
# tensor(3.4375, dtype=torch.bfloat16)
# tensor(0.7891, dtype=torch.bfloat16)
# tensor(2.6875, dtype=torch.bfloat16)
# tensor(2.1562, dtype=torch.bfloat16)
# tensor(4.1875, dtype=torch.bfloat16)
# tensor(4.3438, dtype=torch.bfloat16)
# tensor(5.0625, dtype=torch.bfloat16)
# tensor(2.5469, dtype=torch.bfloat16)
# tensor(11.4375, dtype=torch.bfloat16)
# tensor(5.0625, dtype=torch.bfloat16)
# tensor(1.3594, dtype=torch.bfloat16)
# tensor(2.9062, dtype=torch.bfloat16)
# tensor(2.9688, dtype=torch.bfloat16)
# tensor(0.8242, dtype=torch.bfloat16)
# tensor(1.8516, dtype=torch.bfloat16)
# tensor(0.4492, dtype=torch.bfloat16)
# tensor(2.8438, dtype=torch.bfloat16)
# tensor(4.6250, dtype=torch.bfloat16)
# tensor(0.3105, dtype=torch.bfloat16)
# tensor(4.9375, dtype=torch.bfloat16)
# tensor(10.6250, dtype=torch.bfloat16)
# tensor(6.1250, dtype=torch.bfloat16)
# tensor(1.3281, dtype=torch.bfloat16)
# tensor(2., dtype=torch.bfloat16)
# tensor(3.7031, dtype=torch.bfloat16)
# tensor(1.3203, dtype=torch.bfloat16)
# tensor(1.1406, dtype=torch.bfloat16)
# tensor(0.3457, dtype=torch.bfloat16)
# tensor(2.6875, dtype=torch.bfloat16)
# tensor(3.4531, dtype=torch.bfloat16)
# tensor(1.1875, dtype=torch.bfloat16)
# tensor(1.9219, dtype=torch.bfloat16)
# tensor(1.7109, dtype=torch.bfloat16)
# tensor(0.7383, dtype=torch.bfloat16)
# tensor(2.3594, dtype=torch.bfloat16)
# tensor(2.0156, dtype=torch.bfloat16)
# tensor(1.3516, dtype=torch.bfloat16)
# tensor(1.2422, dtype=torch.bfloat16)
# tensor(5.4062, dtype=torch.bfloat16)
# tensor(9., dtype=torch.bfloat16)
# tensor(10.5625, dtype=torch.bfloat16)
# tensor(2.8906, dtype=torch.bfloat16)
# tensor(26.2500, dtype=torch.bfloat16)
# tensor(0.7383, dtype=torch.bfloat16)
# tensor(2.6719, dtype=torch.bfloat16)
# tensor(2.6875, dtype=torch.bfloat16)
# tensor(1.5000, dtype=torch.bfloat16)
# tensor(1.8516, dtype=torch.bfloat16)
# tensor(1.2891, dtype=torch.bfloat16)
# tensor(1.2969, dtype=torch.bfloat16)
# tensor(1.3594, dtype=torch.bfloat16)
# tensor(1.9609, dtype=torch.bfloat16)
# tensor(1.6641, dtype=torch.bfloat16)
# tensor(2.5000, dtype=torch.bfloat16)
# tensor(1.1484, dtype=torch.bfloat16)
# tensor(2.5000, dtype=torch.bfloat16)
# tensor(0.1494, dtype=torch.bfloat16)
# tensor(3.0938, dtype=torch.bfloat16)
# tensor(8.6875, dtype=torch.bfloat16)
# tensor(1.6172, dtype=torch.bfloat16)
# tensor(2.1875, dtype=torch.bfloat16)
# tensor(8.2500, dtype=torch.bfloat16)
# tensor(1.5938, dtype=torch.bfloat16)
# tensor(0.6914, dtype=torch.bfloat16)
# tensor(0.9570, dtype=torch.bfloat16)
# tensor(0.9414, dtype=torch.bfloat16)
# tensor(1.4453, dtype=torch.bfloat16)
# tensor(47.5000, dtype=torch.bfloat16)
# tensor(2.3281, dtype=torch.bfloat16)
# tensor(0.1895, dtype=torch.bfloat16)
# tensor(0.1895, dtype=torch.bfloat16)
# tensor(2.9375, dtype=torch.bfloat16)
# tensor(0.1797, dtype=torch.bfloat16)
# tensor(5.5625, dtype=torch.bfloat16)
# tensor(1.3047, dtype=torch.bfloat16)
# tensor(1.7422, dtype=torch.bfloat16)
# tensor(5.8750, dtype=torch.bfloat16)
# tensor(5.6562, dtype=torch.bfloat16)
# tensor(6.4375, dtype=torch.bfloat16)
# tensor(1.4766, dtype=torch.bfloat16)
# tensor(1.5547, dtype=torch.bfloat16)
# tensor(3.0156, dtype=torch.bfloat16)
# tensor(1.5000, dtype=torch.bfloat16)
# tensor(4., dtype=torch.bfloat16)
# tensor(1.4531, dtype=torch.bfloat16)
# tensor(4.5312, dtype=torch.bfloat16)
# tensor(0.7031, dtype=torch.bfloat16)
# tensor(4.8438, dtype=torch.bfloat16)
# tensor(9.9375, dtype=torch.bfloat16)
# tensor(6.0312, dtype=torch.bfloat16)
# tensor(0.2217, dtype=torch.bfloat16)
# tensor(1.2969, dtype=torch.bfloat16)
# tensor(3.0156, dtype=torch.bfloat16)
# tensor(0.7266, dtype=torch.bfloat16)
# tensor(2.1562, dtype=torch.bfloat16)
# tensor(1.4844, dtype=torch.bfloat16)
# tensor(5.8125, dtype=torch.bfloat16)
# tensor(1.4609, dtype=torch.bfloat16)
# tensor(2.6094, dtype=torch.bfloat16)
# tensor(4.7188, dtype=torch.bfloat16)
# tensor(0.8008, dtype=torch.bfloat16)
# tensor(15.3750, dtype=torch.bfloat16)
# tensor(0.6797, dtype=torch.bfloat16)
# tensor(53.5000, dtype=torch.bfloat16)
# tensor(6.5000, dtype=torch.bfloat16)
# tensor(6.3125, dtype=torch.bfloat16)
# tensor(0.6133, dtype=torch.bfloat16)
# tensor(11.1250, dtype=torch.bfloat16)
# tensor(11.8125, dtype=torch.bfloat16)
# tensor(0.7109, dtype=torch.bfloat16)
# tensor(4.2500, dtype=torch.bfloat16)
# tensor(524., dtype=torch.bfloat16)
# tensor(1.5391, dtype=torch.bfloat16)
# tensor(2.3281, dtype=torch.bfloat16)
# tensor(0.1953, dtype=torch.bfloat16)
# tensor(5.6562, dtype=torch.bfloat16)
# tensor(2.4062, dtype=torch.bfloat16)
# tensor(0.3594, dtype=torch.bfloat16)
# tensor(0.6953, dtype=torch.bfloat16)
# tensor(17.8750, dtype=torch.bfloat16)
# tensor(10.8125, dtype=torch.bfloat16)
# tensor(10.3750, dtype=torch.bfloat16)
# tensor(1.2656, dtype=torch.bfloat16)
# tensor(2.5000, dtype=torch.bfloat16)
# tensor(1.8047, dtype=torch.bfloat16)
# tensor(6.0312, dtype=torch.bfloat16)
# tensor(11.0625, dtype=torch.bfloat16)
# tensor(13.1250, dtype=torch.bfloat16)
# tensor(0.1963, dtype=torch.bfloat16)
# tensor(0.6289, dtype=torch.bfloat16)
# tensor(1.0469, dtype=torch.bfloat16)
# tensor(2.2656, dtype=torch.bfloat16)
# tensor(2.9688, dtype=torch.bfloat16)
# tensor(0.3027, dtype=torch.bfloat16)
# tensor(2.1719, dtype=torch.bfloat16)
# tensor(1.3672, dtype=torch.bfloat16)
# tensor(1.7500, dtype=torch.bfloat16)
# tensor(4.8125, dtype=torch.bfloat16)
# tensor(0.2451, dtype=torch.bfloat16)
# tensor(2.2188, dtype=torch.bfloat16)
# tensor(5.4375, dtype=torch.bfloat16)
# tensor(5.5625, dtype=torch.bfloat16)
# tensor(6.5938, dtype=torch.bfloat16)
# tensor(6.5938, dtype=torch.bfloat16)
# tensor(0.3691, dtype=torch.bfloat16)

# %%
max_problem = 0
max_problem_layer = ""

for module_name, H in H_dict.items():
    alpha = H.abs().max() / H.abs().mean()
    if alpha > max_problem:
        print("new worst:", module_name, alpha)
        max_problem = alpha
        max_problem_layer = module_name
# Out:
# new worst: model.layers.0.self_attn.q_proj tensor(123392., dtype=torch.bfloat16)
# new worst: model.layers.1.self_attn.q_proj tensor(305152., dtype=torch.bfloat16)
# new worst: model.layers.1.mlp.down_proj tensor(84410368., dtype=torch.bfloat16)
